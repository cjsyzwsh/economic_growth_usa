# %% [markdown]
# # Collect econ attributes at two years (2016 and 2018)
#
#
# - Download the socio-demographics of MA and NH census block groups.
# - Downloaded are ACS2009 5y, ACS 2016 5y and ACS 2018 5y.
# - Notes: CBG is very granular, so many specific variables are not there. I have exhausted all possibilities from ACS.
# - Notes: Q - What?! The ACS2009-5y and other data have DIFFERENT census tract index! As a result, I cannot use ACS2009-5y for comparison purposes. Am I wrong?!
# - 2009, 2016, and 2018 data have different variable list. As a result, the coding needs to be more structured to download all three data sets together. Now it is a bit ad-hoc.

# %%
import pandas as pd
import censusdata
import copy
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Check Information

# %%
# Check the ACS lookup table here:
# https://www.census.gov/programs-surveys/acs/technical-documentation/summary-file-documentation.2015.html
# https://jtleider.github.io/censusdata/

# %%
# 
censusdata.search('acs1', 2015, 'label', 'rent') # check acs1, acs3, acs5, 2010-2020
# Out:
# [('B05001PR_004E',
#   'NATIVITY AND CITIZENSHIP STATUS IN PUERTO RICO',
#   'Estimate!!Total!!U.S. citizen, born abroad of American parent(s)'),
#  ('B05001_004E',
#   'NATIVITY AND CITIZENSHIP STATUS IN THE UNITED STATES',
#   'Estimate!!Total!!U.S. citizen, born abroad of American parent(s)'),
#  ('B05002_012E',
#   'PLACE OF BIRTH BY NATIVITY AND CITIZENSHIP STATUS',
#   'Estimate!!Total!!Native!!Born outside the United States!!Born abroad of American parent(s)'),
#  ('B05009_003E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents'),
#  ('B05009_004E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Child is native'),
#  ('B05009_005E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Child is foreign born'),
#  ('B05009_006E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Both parents native'),
#  ('B05009_007E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Both parents foreign born'),
#  ('B05009_008E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Both parents foreign born!!Child is native'),
#  ('B05009_009E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!Both parents foreign born!!Child is foreign born'),
#  ('B05009_010E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!One native and one foreign-born parent'),
#  ('B05009_011E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!One native and one foreign-born parent!!Child is native'),
#  ('B05009_012E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with two parents!!One native and one foreign-born parent!!Child is foreign born'),
#  ('B05009_013E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent'),
#  ('B05009_014E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Child is native'),
#  ('B05009_015E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Child is foreign born'),
#  ('B05009_016E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Native parent'),
#  ('B05009_017E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Foreign-born parent'),
#  ('B05009_018E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Foreign-born parent!!Child is native'),
#  ('B05009_019E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 6 years!!Living with one parent!!Foreign-born parent!!Child is foreign born'),
#  ('B05009_021E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents'),
#  ('B05009_022E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Child is native'),
#  ('B05009_023E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Child is foreign born'),
#  ('B05009_024E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Both parents native'),
#  ('B05009_025E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Both parents foreign born'),
#  ('B05009_026E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Both parents foreign born!!Child is native'),
#  ('B05009_027E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!Both parents foreign born!!Child is foreign born'),
#  ('B05009_028E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!One native and one foreign-born parent'),
#  ('B05009_029E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!One native and one foreign-born parent!!Child is native'),
#  ('B05009_030E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with two parents!!One native and one foreign-born parent!!Child is foreign born'),
#  ('B05009_031E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent'),
#  ('B05009_032E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Child is native'),
#  ('B05009_033E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Child is foreign born'),
#  ('B05009_034E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Native parent'),
#  ('B05009_035E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Foreign-born parent'),
#  ('B05009_036E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Foreign-born parent!!Child is native'),
#  ('B05009_037E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!6 to 17 years!!Living with one parent!!Foreign-born parent!!Child is foreign born'),
#  ('B05010_003E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with two parents'),
#  ('B05010_004E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with two parents!!Both parents native'),
#  ('B05010_005E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with two parents!!Both parents foreign born'),
#  ('B05010_006E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with two parents!!One native and one foreign-born parent'),
#  ('B05010_007E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with one parent'),
#  ('B05010_008E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with one parent!!Native parent'),
#  ('B05010_009E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!Under 1.00!!Living with one parent!!Foreign-born parent'),
#  ('B05010_011E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with two parents'),
#  ('B05010_012E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with two parents!!Both parents native'),
#  ('B05010_013E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with two parents!!Both parents foreign born'),
#  ('B05010_014E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with two parents!!One native and one foreign-born parent'),
#  ('B05010_015E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with one parent'),
#  ('B05010_016E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with one parent!!Native parent'),
#  ('B05010_017E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!1.00 to 1.99!!Living with one parent!!Foreign-born parent'),
#  ('B05010_019E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with two parents'),
#  ('B05010_020E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with two parents!!Both parents native'),
#  ('B05010_021E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with two parents!!Both parents foreign born'),
#  ('B05010_022E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with two parents!!One native and one foreign-born parent'),
#  ('B05010_023E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with one parent'),
#  ('B05010_024E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with one parent!!Native parent'),
#  ('B05010_025E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total!!2.0  and over!!Living with one parent!!Foreign-born parent'),
#  ('B07001PR_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07001PR_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!1 to 4 years'),
#  ('B07001PR_051E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!5 to 17 years'),
#  ('B07001PR_052E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!18 and 19 years'),
#  ('B07001PR_053E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!20 to 24 years'),
#  ('B07001PR_054E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!25 to 29 years'),
#  ('B07001PR_055E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!30 to 34 years'),
#  ('B07001PR_056E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!35 to 39 years'),
#  ('B07001PR_057E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!40 to 44 years'),
#  ('B07001PR_058E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!45 to 49 years'),
#  ('B07001PR_059E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!50 to 54 years'),
#  ('B07001PR_060E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!55 to 59 years'),
#  ('B07001PR_061E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!60 to 64 years'),
#  ('B07001PR_062E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!65 to 69 years'),
#  ('B07001PR_063E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!70 to 74 years'),
#  ('B07001PR_064E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!75 years and over'),
#  ('B07001_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07001_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!1 to 4 years'),
#  ('B07001_051E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!5 to 17 years'),
#  ('B07001_052E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!18 and 19 years'),
#  ('B07001_053E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!20 to 24 years'),
#  ('B07001_054E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!25 to 29 years'),
#  ('B07001_055E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!30 to 34 years'),
#  ('B07001_056E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!35 to 39 years'),
#  ('B07001_057E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!40 to 44 years'),
#  ('B07001_058E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!45 to 49 years'),
#  ('B07001_059E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!50 to 54 years'),
#  ('B07001_060E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!55 to 59 years'),
#  ('B07001_061E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!60 to 64 years'),
#  ('B07001_062E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!65 to 69 years'),
#  ('B07001_063E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!70 to 74 years'),
#  ('B07001_064E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!75 years and over'),
#  ('B07001_065E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07001_066E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!1 to 4 years'),
#  ('B07001_067E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!5 to 17 years'),
#  ('B07001_068E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!18 and 19 years'),
#  ('B07001_069E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!20 to 24 years'),
#  ('B07001_070E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!25 to 29 years'),
#  ('B07001_071E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!30 to 34 years'),
#  ('B07001_072E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!35 to 39 years'),
#  ('B07001_073E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!40 to 44 years'),
#  ('B07001_074E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!45 to 49 years'),
#  ('B07001_075E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!50 to 54 years'),
#  ('B07001_076E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!55 to 59 years'),
#  ('B07001_077E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!60 to 64 years'),
#  ('B07001_078E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!65 to 69 years'),
#  ('B07001_079E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!70 to 74 years'),
#  ('B07001_080E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!75 years and over'),
#  ('B07002PR_004E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Median age!!Total!!Moved from different municipio'),
#  ('B07002_004E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Median age!!Total!!Moved from different county within same state'),
#  ('B07002_005E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Median age!!Total!!Moved from different state'),
#  ('B07003PR_010E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07003PR_011E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Male'),
#  ('B07003PR_012E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Female'),
#  ('B07003_010E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07003_011E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Male'),
#  ('B07003_012E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Female'),
#  ('B07003_013E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07003_014E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Male'),
#  ('B07003_015E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Female'),
#  ('B07004APR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004A_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004A_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004BPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004B_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004B_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004CPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004C_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004C_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004D_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004D_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004E_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004E_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004FPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004F_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004F_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004GPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004G_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004G_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004HPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004H_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004H_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07004IPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07004I_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07004I_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07007PR_016E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07007PR_017E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Native'),
#  ('B07007PR_018E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Foreign born'),
#  ('B07007PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Foreign born!!Naturalized U.S. citizen'),
#  ('B07007PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Foreign born!!Not a U.S. citizen'),
#  ('B07007_016E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07007_017E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Native'),
#  ('B07007_018E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Foreign born'),
#  ('B07007_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Foreign born!!Naturalized U.S. citizen'),
#  ('B07007_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Foreign born!!Not a U.S. citizen'),
#  ('B07007_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07007_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Native'),
#  ('B07007_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Foreign born'),
#  ('B07007_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Foreign born!!Naturalized U.S. citizen'),
#  ('B07007_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Foreign born!!Not a U.S. citizen'),
#  ('B07008PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07008PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Never married'),
#  ('B07008PR_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Now married, except separated'),
#  ('B07008PR_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Divorced'),
#  ('B07008PR_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Separated'),
#  ('B07008PR_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Widowed'),
#  ('B07008_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07008_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Never married'),
#  ('B07008_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Now married, except separated'),
#  ('B07008_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Divorced'),
#  ('B07008_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Separated'),
#  ('B07008_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Widowed'),
#  ('B07008_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07008_026E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Never married'),
#  ('B07008_027E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Now married, except separated'),
#  ('B07008_028E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Divorced'),
#  ('B07008_029E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Separated'),
#  ('B07008_030E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Widowed'),
#  ('B07009PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07009PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Less than high school graduate'),
#  ('B07009PR_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!High school graduate (includes equivalency)'),
#  ('B07009PR_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   "Estimate!!Total!!Moved from different municipio!!Some college or associate's degree"),
#  ('B07009PR_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   "Estimate!!Total!!Moved from different municipio!!Bachelor's degree"),
#  ('B07009PR_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!Graduate or professional degree'),
#  ('B07009_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07009_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Less than high school graduate'),
#  ('B07009_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!High school graduate (includes equivalency)'),
#  ('B07009_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total!!Moved from different county within same state!!Some college or associate's degree"),
#  ('B07009_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total!!Moved from different county within same state!!Bachelor's degree"),
#  ('B07009_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!Graduate or professional degree'),
#  ('B07009_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07009_026E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Less than high school graduate'),
#  ('B07009_027E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!High school graduate (includes equivalency)'),
#  ('B07009_028E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total!!Moved from different state!!Some college or associate's degree"),
#  ('B07009_029E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total!!Moved from different state!!Bachelor's degree"),
#  ('B07009_030E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!Graduate or professional degree'),
#  ('B07010PR_034E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio'),
#  ('B07010PR_035E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!No income'),
#  ('B07010PR_036E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income'),
#  ('B07010PR_037E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$1 to $9,999 or loss'),
#  ('B07010PR_038E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$10,000 to $14,999'),
#  ('B07010PR_039E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$15,000 to $24,999'),
#  ('B07010PR_040E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$25,000 to $34,999'),
#  ('B07010PR_041E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$35,000 to $49,999'),
#  ('B07010PR_042E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$50,000 to $64,999'),
#  ('B07010PR_043E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$65,000 to $74,999'),
#  ('B07010PR_044E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total!!Moved from different municipio!!With income!!$75,000 or more'),
#  ('B07010_034E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state'),
#  ('B07010_035E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!No income'),
#  ('B07010_036E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income'),
#  ('B07010_037E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$1 to $9,999 or loss'),
#  ('B07010_038E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$10,000 to $14,999'),
#  ('B07010_039E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$15,000 to $24,999'),
#  ('B07010_040E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$25,000 to $34,999'),
#  ('B07010_041E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$35,000 to $49,999'),
#  ('B07010_042E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$50,000 to $64,999'),
#  ('B07010_043E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$65,000 to $74,999'),
#  ('B07010_044E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different county within same state!!With income!!$75,000 or more'),
#  ('B07010_045E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state'),
#  ('B07010_046E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!No income'),
#  ('B07010_047E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income'),
#  ('B07010_048E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$1 to $9,999 or loss'),
#  ('B07010_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$10,000 to $14,999'),
#  ('B07010_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$15,000 to $24,999'),
#  ('B07010_051E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$25,000 to $34,999'),
#  ('B07010_052E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$35,000 to $49,999'),
#  ('B07010_053E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2015 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total!!Moved from different state!!With income!!$50,000 to $64,999'),
#  ('B07010_054E',
# ...
#  ('B25007_018E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Householder 60 to 64 years'),
#  ('B25007_019E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Householder 65 to 74 years'),
#  ('B25007_020E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Householder 75 to 84 years'),
#  ('B25007_021E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Householder 85 years and over'),
#  ('B25008_003E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25009_010E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25009_011E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!1-person household'),
#  ('B25009_012E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!2-person household'),
#  ('B25009_013E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!3-person household'),
#  ('B25009_014E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!4-person household'),
#  ('B25009_015E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!5-person household'),
#  ('B25009_016E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!6-person household'),
#  ('B25009_017E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total!!Renter occupied!!7-or-more person household'),
#  ('B25010_003E',
#   'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25011_026E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25011_027E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households'),
#  ('B25011_028E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Married-couple family'),
#  ('B25011_029E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Married-couple family!!Householder 15 to 34 years'),
#  ('B25011_030E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Married-couple family!!Householder 35 to 64 years'),
#  ('B25011_031E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Married-couple family!!Householder 65 years and over'),
#  ('B25011_032E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family'),
#  ('B25011_033E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Male householder, no wife present'),
#  ('B25011_034E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Male householder, no wife present!!Householder 15 to 34 years'),
#  ('B25011_035E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Male householder, no wife present!!Householder 35 to 64 years'),
#  ('B25011_036E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Male householder, no wife present!!Householder 65 years and over'),
#  ('B25011_037E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Female householder, no husband present'),
#  ('B25011_038E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Female householder, no husband present!!Householder 15 to 34 years'),
#  ('B25011_039E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Female householder, no husband present!!Householder 35 to 64 years'),
#  ('B25011_040E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Female householder, no husband present!!Householder 65 years and over'),
#  ('B25011_041E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households'),
#  ('B25011_042E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder living alone'),
#  ('B25011_043E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder living alone!!Householder 15 to 34 years'),
#  ('B25011_044E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder living alone!!Householder 35 to 64 years'),
#  ('B25011_045E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder living alone!!Householder 65 years and over'),
#  ('B25011_046E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder not living alone'),
#  ('B25011_047E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder not living alone!!Householder 15 to 34 years'),
#  ('B25011_048E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder not living alone!!Householder 35 to 64 years'),
#  ('B25011_049E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter occupied!!Nonfamily households!!Householder not living alone!!Householder 65 years and over'),
#  ('B25012_010E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units'),
#  ('B25012_011E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18'),
#  ('B25012_012E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18!!With own children of the householder under 18'),
#  ('B25012_013E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18!!With own children of the householder under 18!!Under 6 years only'),
#  ('B25012_014E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18!!With own children of the householder under 18!!Under 6 years and 6 to 17 years'),
#  ('B25012_015E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18!!With own children of the householder under 18!!6 to 17 years'),
#  ('B25012_016E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!With related children of the householder under 18!!No own children of the householder under 18'),
#  ('B25012_017E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total!!Renter-occupied housing units!!No related children of the householder under 18'),
#  ('B25013_007E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter-occupied housing units'),
#  ('B25013_008E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter-occupied housing units!!Less than high school graduate'),
#  ('B25013_009E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total!!Renter-occupied housing units!!High school graduate (including equivalency)'),
#  ('B25013_010E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   "Estimate!!Total!!Renter-occupied housing units!!Some college or associate's degree"),
#  ('B25013_011E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   "Estimate!!Total!!Renter-occupied housing units!!Bachelor's degree or higher"),
#  ('B25014_008E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25014_009E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!0.50 or less occupants per room'),
#  ('B25014_010E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!0.51 to 1.00 occupants per room'),
#  ('B25014_011E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!1.01 to 1.50 occupants per room'),
#  ('B25014_012E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!1.51 to 2.00 occupants per room'),
#  ('B25014_013E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!2.01 or more occupants per room'),
#  ('B25015_015E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25015_016E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 15 to 34 years'),
#  ('B25015_017E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 15 to 34 years!!1.00 or less occupants per room'),
#  ('B25015_018E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 15 to 34 years!!1.01 to 1.50 occupants per room'),
#  ('B25015_019E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 15 to 34 years!!1.51 or more occupants per room'),
#  ('B25015_020E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 35 to 64 years'),
#  ('B25015_021E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 35 to 64 years!!1.00 or less occupants per room'),
#  ('B25015_022E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 35 to 64 years!!1.01 to 1.50 occupants per room'),
#  ('B25015_023E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 35 to 64 years!!1.51 or more occupants per room'),
#  ('B25015_024E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 65 years and over'),
#  ('B25015_025E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 65 years and over!!1.00 or less occupants per room'),
#  ('B25015_026E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 65 years and over!!1.01 to 1.50 occupants per room'),
#  ('B25015_027E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Householder 65 years and over!!1.51 or more occupants per room'),
#  ('B25016_011E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied'),
#  ('B25016_012E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Complete plumbing facilities'),
#  ('B25016_013E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Complete plumbing facilities!!1.00 or less occupants per room'),
#  ('B25016_014E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Complete plumbing facilities!!1.01 to 1.50 occupants per room'),
#  ('B25016_015E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Complete plumbing facilities!!1.51 or more occupants per room'),
#  ('B25016_016E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Lacking complete plumbing facilities'),
#  ('B25016_017E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Lacking complete plumbing facilities!!1.00 or less occupants per room'),
#  ('B25016_018E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Lacking complete plumbing facilities!!1.01 to 1.50 occupants per room'),
#  ('B25016_019E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total!!Renter occupied!!Lacking complete plumbing facilities!!1.51 or more occupants per room'),
#  ('B25020_012E', 'TENURE BY ROOMS', 'Estimate!!Total!!Renter occupied'),
#  ('B25020_013E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!1 room'),
#  ('B25020_014E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!2 rooms'),
#  ('B25020_015E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!3 rooms'),
#  ('B25020_016E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!4 rooms'),
#  ('B25020_017E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!5 rooms'),
#  ('B25020_018E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!6 rooms'),
#  ('B25020_019E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!7 rooms'),
#  ('B25020_020E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!8 rooms'),
#  ('B25020_021E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total!!Renter occupied!!9 or more rooms'),
#  ('B25021_003E',
#   'MEDIAN NUMBER OF ROOMS BY TENURE',
#   'Estimate!!Median number of rooms!!Renter occupied'),
#  ('B25022_003E',
#   'AGGREGATE NUMBER OF ROOMS BY TENURE',
#   'Estimate!!Aggregate number of rooms!!Renter occupied'),
#  ('B25026_009E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied'),
#  ('B25026_010E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 2015 or later'),
#  ('B25026_011E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 2010 to 2014'),
#  ('B25026_012E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 2000 to 2009'),
#  ('B25026_013E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 1990 to 1999'),
#  ('B25026_014E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 1980 to 1989'),
#  ('B25026_015E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units!!Renter occupied!!Moved in 1979 or earlier'),
#  ('B25031_001E',
#   'MEDIAN GROSS RENT BY BEDROOMS',
#   'Estimate!!Median gross rent!!Total'),
#  ('B25031_002E',
#   'MEDIAN GROSS RENT BY BEDROOMS',
#   'Estimate!!Median gross rent!!Total!!No bedroom'),
#  ('B25031_003E',
#   'MEDIAN GROSS RENT BY BEDROOMS',
#   'Estimate!!Median gross rent!!Total!!1 bedroom'),
#  ...]

# %%
# 
censusdata.search('acs1', 2019, 'label', 'rent') # check acs1, acs3, acs5, 2010-2020
# Out:
# [('B05001PR_004E',
#   'NATIVITY AND CITIZENSHIP STATUS IN PUERTO RICO',
#   'Estimate!!Total:!!U.S. citizen, born abroad of American parent(s)'),
#  ('B05001_004E',
#   'NATIVITY AND CITIZENSHIP STATUS IN THE UNITED STATES',
#   'Estimate!!Total:!!U.S. citizen, born abroad of American parent(s)'),
#  ('B05002_012E',
#   'PLACE OF BIRTH BY NATIVITY AND CITIZENSHIP STATUS',
#   'Estimate!!Total:!!Native:!!Born outside the United States:!!Born abroad of American parent(s)'),
#  ('B05009_003E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:'),
#  ('B05009_004E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Child is native'),
#  ('B05009_005E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Child is foreign born'),
#  ('B05009_006E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Both parents native'),
#  ('B05009_007E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Both parents foreign born:'),
#  ('B05009_008E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Both parents foreign born:!!Child is native'),
#  ('B05009_009E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!Both parents foreign born:!!Child is foreign born'),
#  ('B05009_010E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!One native and one foreign-born parent:'),
#  ('B05009_011E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!One native and one foreign-born parent:!!Child is native'),
#  ('B05009_012E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with two parents:!!One native and one foreign-born parent:!!Child is foreign born'),
#  ('B05009_013E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:'),
#  ('B05009_014E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Child is native'),
#  ('B05009_015E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Child is foreign born'),
#  ('B05009_016E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Native parent'),
#  ('B05009_017E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Foreign-born parent:'),
#  ('B05009_018E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Foreign-born parent:!!Child is native'),
#  ('B05009_019E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 6 years:!!Living with one parent:!!Foreign-born parent:!!Child is foreign born'),
#  ('B05009_021E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:'),
#  ('B05009_022E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Child is native'),
#  ('B05009_023E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Child is foreign born'),
#  ('B05009_024E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Both parents native'),
#  ('B05009_025E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Both parents foreign born:'),
#  ('B05009_026E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Both parents foreign born:!!Child is native'),
#  ('B05009_027E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!Both parents foreign born:!!Child is foreign born'),
#  ('B05009_028E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!One native and one foreign-born parent:'),
#  ('B05009_029E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!One native and one foreign-born parent:!!Child is native'),
#  ('B05009_030E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with two parents:!!One native and one foreign-born parent:!!Child is foreign born'),
#  ('B05009_031E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:'),
#  ('B05009_032E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Child is native'),
#  ('B05009_033E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Child is foreign born'),
#  ('B05009_034E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Native parent'),
#  ('B05009_035E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Foreign-born parent:'),
#  ('B05009_036E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Foreign-born parent:!!Child is native'),
#  ('B05009_037E',
#   'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!6 to 17 years:!!Living with one parent:!!Foreign-born parent:!!Child is foreign born'),
#  ('B05010_003E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with two parents:'),
#  ('B05010_004E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with two parents:!!Both parents native'),
#  ('B05010_005E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with two parents:!!Both parents foreign born'),
#  ('B05010_006E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with two parents:!!One native and one foreign-born parent'),
#  ('B05010_007E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with one parent:'),
#  ('B05010_008E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with one parent:!!Native parent'),
#  ('B05010_009E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!Under 1.00:!!Living with one parent:!!Foreign-born parent'),
#  ('B05010_011E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with two parents:'),
#  ('B05010_012E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with two parents:!!Both parents native'),
#  ('B05010_013E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with two parents:!!Both parents foreign born'),
#  ('B05010_014E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with two parents:!!One native and one foreign-born parent'),
#  ('B05010_015E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with one parent:'),
#  ('B05010_016E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with one parent:!!Native parent'),
#  ('B05010_017E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!1.00 to 1.99:!!Living with one parent:!!Foreign-born parent'),
#  ('B05010_019E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with two parents:'),
#  ('B05010_020E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with two parents:!!Both parents native'),
#  ('B05010_021E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with two parents:!!Both parents foreign born'),
#  ('B05010_022E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with two parents:!!One native and one foreign-born parent'),
#  ('B05010_023E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with one parent:'),
#  ('B05010_024E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with one parent:!!Native parent'),
#  ('B05010_025E',
#   'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'Estimate!!Total:!!2.00 and over:!!Living with one parent:!!Foreign-born parent'),
#  ('B07001PR_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07001PR_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!1 to 4 years'),
#  ('B07001PR_051E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!5 to 17 years'),
#  ('B07001PR_052E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!18 and 19 years'),
#  ('B07001PR_053E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!20 to 24 years'),
#  ('B07001PR_054E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!25 to 29 years'),
#  ('B07001PR_055E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!30 to 34 years'),
#  ('B07001PR_056E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!35 to 39 years'),
#  ('B07001PR_057E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!40 to 44 years'),
#  ('B07001PR_058E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!45 to 49 years'),
#  ('B07001PR_059E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!50 to 54 years'),
#  ('B07001PR_060E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!55 to 59 years'),
#  ('B07001PR_061E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!60 to 64 years'),
#  ('B07001PR_062E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!65 to 69 years'),
#  ('B07001PR_063E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!70 to 74 years'),
#  ('B07001PR_064E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!75 years and over'),
#  ('B07001_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07001_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!1 to 4 years'),
#  ('B07001_051E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!5 to 17 years'),
#  ('B07001_052E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!18 and 19 years'),
#  ('B07001_053E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!20 to 24 years'),
#  ('B07001_054E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!25 to 29 years'),
#  ('B07001_055E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!30 to 34 years'),
#  ('B07001_056E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!35 to 39 years'),
#  ('B07001_057E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!40 to 44 years'),
#  ('B07001_058E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!45 to 49 years'),
#  ('B07001_059E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!50 to 54 years'),
#  ('B07001_060E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!55 to 59 years'),
#  ('B07001_061E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!60 to 64 years'),
#  ('B07001_062E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!65 to 69 years'),
#  ('B07001_063E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!70 to 74 years'),
#  ('B07001_064E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!75 years and over'),
#  ('B07001_065E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07001_066E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!1 to 4 years'),
#  ('B07001_067E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!5 to 17 years'),
#  ('B07001_068E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!18 and 19 years'),
#  ('B07001_069E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!20 to 24 years'),
#  ('B07001_070E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!25 to 29 years'),
#  ('B07001_071E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!30 to 34 years'),
#  ('B07001_072E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!35 to 39 years'),
#  ('B07001_073E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!40 to 44 years'),
#  ('B07001_074E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!45 to 49 years'),
#  ('B07001_075E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!50 to 54 years'),
#  ('B07001_076E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!55 to 59 years'),
#  ('B07001_077E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!60 to 64 years'),
#  ('B07001_078E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!65 to 69 years'),
#  ('B07001_079E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!70 to 74 years'),
#  ('B07001_080E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!75 years and over'),
#  ('B07002PR_004E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Median age --!!Total:!!Moved from different municipio'),
#  ('B07002_004E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Median age --!!Total:!!Moved from different county within same state'),
#  ('B07002_005E',
#   'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Median age --!!Total:!!Moved from different state'),
#  ('B07003PR_010E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07003PR_011E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Male'),
#  ('B07003PR_012E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Female'),
#  ('B07003_010E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07003_011E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Male'),
#  ('B07003_012E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Female'),
#  ('B07003_013E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07003_014E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Male'),
#  ('B07003_015E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Female'),
#  ('B07004APR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004A_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004A_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004BPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004B_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004B_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (BLACK OR AFRICAN AMERICAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004CPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004C_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004C_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004DPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004D_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004D_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004EPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004E_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004E_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004FPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004F_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004F_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004GPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004G_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004G_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004HPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004H_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004H_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07004IPR_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio'),
#  ('B07004I_004E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state'),
#  ('B07004I_005E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state'),
#  ('B07007PR_016E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07007PR_017E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Native'),
#  ('B07007PR_018E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Foreign born:'),
#  ('B07007PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B07007PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Foreign born:!!Not a U.S. citizen'),
#  ('B07007_016E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07007_017E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Native'),
#  ('B07007_018E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Foreign born:'),
#  ('B07007_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B07007_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Foreign born:!!Not a U.S. citizen'),
#  ('B07007_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07007_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Native'),
#  ('B07007_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Foreign born:'),
#  ('B07007_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Foreign born:!!Naturalized U.S. citizen'),
#  ('B07007_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Foreign born:!!Not a U.S. citizen'),
#  ('B07008PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07008PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Never married'),
#  ('B07008PR_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Now married, except separated'),
#  ('B07008PR_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Divorced'),
#  ('B07008PR_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Separated'),
#  ('B07008PR_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Widowed'),
#  ('B07008_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07008_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Never married'),
#  ('B07008_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Now married, except separated'),
#  ('B07008_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Divorced'),
#  ('B07008_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Separated'),
#  ('B07008_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Widowed'),
#  ('B07008_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07008_026E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Never married'),
#  ('B07008_027E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Now married, except separated'),
#  ('B07008_028E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Divorced'),
#  ('B07008_029E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Separated'),
#  ('B07008_030E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Widowed'),
#  ('B07009PR_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07009PR_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Less than high school graduate'),
#  ('B07009PR_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!High school graduate (includes equivalency)'),
#  ('B07009PR_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   "Estimate!!Total:!!Moved from different municipio:!!Some college or associate's degree"),
#  ('B07009PR_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   "Estimate!!Total:!!Moved from different municipio:!!Bachelor's degree"),
#  ('B07009PR_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!Graduate or professional degree'),
#  ('B07009_019E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07009_020E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Less than high school graduate'),
#  ('B07009_021E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!High school graduate (includes equivalency)'),
#  ('B07009_022E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total:!!Moved from different county within same state:!!Some college or associate's degree"),
#  ('B07009_023E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total:!!Moved from different county within same state:!!Bachelor's degree"),
#  ('B07009_024E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!Graduate or professional degree'),
#  ('B07009_025E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07009_026E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Less than high school graduate'),
#  ('B07009_027E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!High school graduate (includes equivalency)'),
#  ('B07009_028E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total:!!Moved from different state:!!Some college or associate's degree"),
#  ('B07009_029E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   "Estimate!!Total:!!Moved from different state:!!Bachelor's degree"),
#  ('B07009_030E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!Graduate or professional degree'),
#  ('B07010PR_034E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:'),
#  ('B07010PR_035E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!No income'),
#  ('B07010PR_036E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:'),
#  ('B07010PR_037E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$1 to $9,999 or loss'),
#  ('B07010PR_038E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$10,000 to $14,999'),
#  ('B07010PR_039E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$15,000 to $24,999'),
#  ('B07010PR_040E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$25,000 to $34,999'),
#  ('B07010PR_041E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$35,000 to $49,999'),
#  ('B07010PR_042E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$50,000 to $64,999'),
#  ('B07010PR_043E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$65,000 to $74,999'),
#  ('B07010PR_044E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'Estimate!!Total:!!Moved from different municipio:!!With income:!!$75,000 or more'),
#  ('B07010_034E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:'),
#  ('B07010_035E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!No income'),
#  ('B07010_036E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:'),
#  ('B07010_037E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$1 to $9,999 or loss'),
#  ('B07010_038E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$10,000 to $14,999'),
#  ('B07010_039E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$15,000 to $24,999'),
#  ('B07010_040E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$25,000 to $34,999'),
#  ('B07010_041E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$35,000 to $49,999'),
#  ('B07010_042E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$50,000 to $64,999'),
#  ('B07010_043E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$65,000 to $74,999'),
#  ('B07010_044E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different county within same state:!!With income:!!$75,000 or more'),
#  ('B07010_045E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:'),
#  ('B07010_046E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!No income'),
#  ('B07010_047E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!With income:'),
#  ('B07010_048E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!With income:!!$1 to $9,999 or loss'),
#  ('B07010_049E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!With income:!!$10,000 to $14,999'),
#  ('B07010_050E',
#   'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'Estimate!!Total:!!Moved from different state:!!With income:!!$15,000 to $24,999'),
#  ('B07010_051E',
# ...
#  ('B25007_012E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25007_013E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 15 to 24 years'),
#  ('B25007_014E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 25 to 34 years'),
#  ('B25007_015E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 35 to 44 years'),
#  ('B25007_016E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 45 to 54 years'),
#  ('B25007_017E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 55 to 59 years'),
#  ('B25007_018E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 60 to 64 years'),
#  ('B25007_019E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 65 to 74 years'),
#  ('B25007_020E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 75 to 84 years'),
#  ('B25007_021E',
#   'TENURE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Householder 85 years and over'),
#  ('B25008_003E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE',
#   'Estimate!!Total:!!Renter occupied'),
#  ('B25009_010E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25009_011E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!1-person household'),
#  ('B25009_012E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!2-person household'),
#  ('B25009_013E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!3-person household'),
#  ('B25009_014E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!4-person household'),
#  ('B25009_015E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!5-person household'),
#  ('B25009_016E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!6-person household'),
#  ('B25009_017E',
#   'TENURE BY HOUSEHOLD SIZE',
#   'Estimate!!Total:!!Renter occupied:!!7-or-more person household'),
#  ('B25010_003E',
#   'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE',
#   'Estimate!!Average household size --!!Total:!!Renter occupied'),
#  ('B25011_026E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25011_027E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:'),
#  ('B25011_028E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Married-couple family:'),
#  ('B25011_029E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Married-couple family:!!Householder 15 to 34 years'),
#  ('B25011_030E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Married-couple family:!!Householder 35 to 64 years'),
#  ('B25011_031E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Married-couple family:!!Householder 65 years and over'),
#  ('B25011_032E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:'),
#  ('B25011_033E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Male householder, no spouse present:'),
#  ('B25011_034E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Male householder, no spouse present:!!Householder 15 to 34 years'),
#  ('B25011_035E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Male householder, no spouse present:!!Householder 35 to 64 years'),
#  ('B25011_036E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Male householder, no spouse present:!!Householder 65 years and over'),
#  ('B25011_037E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Female householder, no spouse present:'),
#  ('B25011_038E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Female householder, no spouse present:!!Householder 15 to 34 years'),
#  ('B25011_039E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Female householder, no spouse present:!!Householder 35 to 64 years'),
#  ('B25011_040E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Family households:!!Other family:!!Female householder, no spouse present:!!Householder 65 years and over'),
#  ('B25011_041E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:'),
#  ('B25011_042E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder living alone:'),
#  ('B25011_043E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder living alone:!!Householder 15 to 34 years'),
#  ('B25011_044E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder living alone:!!Householder 35 to 64 years'),
#  ('B25011_045E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder living alone:!!Householder 65 years and over'),
#  ('B25011_046E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder not living alone:'),
#  ('B25011_047E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder not living alone:!!Householder 15 to 34 years'),
#  ('B25011_048E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder not living alone:!!Householder 35 to 64 years'),
#  ('B25011_049E',
#   'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter occupied:!!Nonfamily households:!!Householder not living alone:!!Householder 65 years and over'),
#  ('B25012_010E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:'),
#  ('B25012_011E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:'),
#  ('B25012_012E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:!!With own children of the householder under 18:'),
#  ('B25012_013E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:!!With own children of the householder under 18:!!Under 6 years only'),
#  ('B25012_014E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:!!With own children of the householder under 18:!!Under 6 years and 6 to 17 years'),
#  ('B25012_015E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:!!With own children of the householder under 18:!!6 to 17 years'),
#  ('B25012_016E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!With related children of the householder under 18:!!No own children of the householder under 18'),
#  ('B25012_017E',
#   'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'Estimate!!Total:!!Renter-occupied housing units:!!No related children of the householder under 18'),
#  ('B25013_007E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter-occupied housing units:'),
#  ('B25013_008E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter-occupied housing units:!!Less than high school graduate'),
#  ('B25013_009E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'Estimate!!Total:!!Renter-occupied housing units:!!High school graduate (including equivalency)'),
#  ('B25013_010E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   "Estimate!!Total:!!Renter-occupied housing units:!!Some college or associate's degree"),
#  ('B25013_011E',
#   'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   "Estimate!!Total:!!Renter-occupied housing units:!!Bachelor's degree or higher"),
#  ('B25014_008E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25014_009E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!0.50 or less occupants per room'),
#  ('B25014_010E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!0.51 to 1.00 occupants per room'),
#  ('B25014_011E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!1.01 to 1.50 occupants per room'),
#  ('B25014_012E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!1.51 to 2.00 occupants per room'),
#  ('B25014_013E',
#   'TENURE BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!2.01 or more occupants per room'),
#  ('B25015_015E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25015_016E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:'),
#  ('B25015_017E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:!!1.00 or less occupants per room'),
#  ('B25015_018E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:!!1.01 to 1.50 occupants per room'),
#  ('B25015_019E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 15 to 34 years:!!1.51 or more occupants per room'),
#  ('B25015_020E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 35 to 64 years:'),
#  ('B25015_021E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 35 to 64 years:!!1.00 or less occupants per room'),
#  ('B25015_022E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 35 to 64 years:!!1.01 to 1.50 occupants per room'),
#  ('B25015_023E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 35 to 64 years:!!1.51 or more occupants per room'),
#  ('B25015_024E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 65 years and over:'),
#  ('B25015_025E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 65 years and over:!!1.00 or less occupants per room'),
#  ('B25015_026E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 65 years and over:!!1.01 to 1.50 occupants per room'),
#  ('B25015_027E',
#   'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Householder 65 years and over:!!1.51 or more occupants per room'),
#  ('B25016_011E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:'),
#  ('B25016_012E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Complete plumbing facilities:'),
#  ('B25016_013E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Complete plumbing facilities:!!1.00 or less occupants per room'),
#  ('B25016_014E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Complete plumbing facilities:!!1.01 to 1.50 occupants per room'),
#  ('B25016_015E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Complete plumbing facilities:!!1.51 or more occupants per room'),
#  ('B25016_016E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Lacking complete plumbing facilities:'),
#  ('B25016_017E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Lacking complete plumbing facilities:!!1.00 or less occupants per room'),
#  ('B25016_018E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Lacking complete plumbing facilities:!!1.01 to 1.50 occupants per room'),
#  ('B25016_019E',
#   'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'Estimate!!Total:!!Renter occupied:!!Lacking complete plumbing facilities:!!1.51 or more occupants per room'),
#  ('B25020_012E', 'TENURE BY ROOMS', 'Estimate!!Total:!!Renter occupied:'),
#  ('B25020_013E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!1 room'),
#  ('B25020_014E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!2 rooms'),
#  ('B25020_015E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!3 rooms'),
#  ('B25020_016E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!4 rooms'),
#  ('B25020_017E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!5 rooms'),
#  ('B25020_018E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!6 rooms'),
#  ('B25020_019E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!7 rooms'),
#  ('B25020_020E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!8 rooms'),
#  ('B25020_021E',
#   'TENURE BY ROOMS',
#   'Estimate!!Total:!!Renter occupied:!!9 or more rooms'),
#  ('B25021_003E',
#   'MEDIAN NUMBER OF ROOMS BY TENURE',
#   'Estimate!!Median number of rooms --!!Total:!!Renter occupied'),
#  ('B25022_003E',
#   'AGGREGATE NUMBER OF ROOMS BY TENURE',
#   'Estimate!!Aggregate number of rooms:!!Renter occupied'),
#  ('B25026_009E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units:!!Renter occupied:'),
#  ('B25026_010E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units:!!Renter occupied:!!Moved in 2017 or later'),
#  ('B25026_011E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units:!!Renter occupied:!!Moved in 2015 to 2016'),
#  ('B25026_012E',
#   'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'Estimate!!Total population in occupied housing units:!!Renter occupied:!!Moved in 2010 to 2014'),
#  ...]

# %%
censusdata.printtable(censusdata.censustable('acs5', 2009, 'B01002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B01002_001E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Total                          | float
# B01002_002E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Male                           | float
# B01002_003E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Female                         | float
# -------------------------------------------------------------------------------------------------------------------

# %%
# define variable list
# Include population, sex, age, race, income, travel, education, and properties.
# in 2009, the rows of B15003, B23035, B25031, B25111 did not exist. These rows exist in 2016 and 2018.
var_list = [
# population        
            'B01003_001E', 
            'B01001_001E', 'B01001_002E', 'B01001_026E', 
            'B01002_001E',
# households
            'B11001_001E',
# race
            'B02001_001E', 'B02001_002E', 'B02001_003E', 'B02001_004E', 'B02001_005E', 
# income info (a lot of NAs)    
            'B06010_001E', 'B06010_002E', 'B06010_003E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E', 'B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
            'B06011_001E',      
# travel
#             'B08101_001E', 'B08101_009E', 'B08101_017E', 'B08101_025E', 'B08101_033E', 'B08101_041E', 'B08101_049E', 
#             'B08015_001E', 
            'B08301_001E', 'B08301_002E', 'B08301_010E', 'B08301_016E', 'B08301_018E', 'B08301_019E', 'B08301_021E', 
# education                         
            'B15001_001E',
            'B15001_017E', 'B15001_018E', 'B15001_025E', 'B15001_026E', 'B15001_033E', 'B15001_034E', 'B15001_041E', 'B15001_042E', 
            'B15001_058E', 'B15001_059E', 'B15001_066E', 'B15001_067E', 'B15001_074E', 'B15001_075E', 'B15001_082E', 'B15001_083E',
            'B15003_001E', 'B15003_022E', 'B15003_023E', 'B15003_025E', 
# income info (more complete)                       
            'B19013_001E', 'B19301_001E', 
# employement
            'B23025_001E', 'B23025_002E', 'B23025_007E', 
# properties            
            'B25002_001E', 'B25002_002E', 'B25002_003E',             
            'B25064_001E', 
#             'B25031_002E', 'B25031_003E', 'B25031_004E', 'B25031_005E', 'B25031_006E', 'B25031_007E', 
#             'B25111_002E', 'B25111_003E', 'B25111_004E', 'B25111_005E', 'B25111_006E', 'B25111_007E', 'B25111_008E', 'B25111_009E', 'B25111_010E', 'B25111_011E',
            'B25075_001E', 'B25077_001E',
# imputation
            'B99082_001E'
           ]

var_names = [
# population
             'pop_total', 
             'sex_total', 'sex_male', 'sex_female',
             'age_median',
# hosueholds
             'households',
# race             
             'race_total', 'race_white', 'race_black', 'race_native', 'race_asian',
# income info (a lot of NAs)
             'inc_total_pop', 'inc_no_pop', 'inc_with_pop', 'inc_pop_10k', 'inc_pop_1k_15k', 'inc_pop_15k_25k', 'inc_pop_25k_35k', 'inc_pop_35k_50k', 'inc_pop_50k_65k', 'inc_pop_65k_75k', 'inc_pop_75k',
             'inc_median_ind', 
# travel
#              'travel_total_to_work', 'travel_single_driving_to_work', 'travel_carpool_to_work', 'travel_public_transit_to_work', 'travel_walking_to_work', 'travel_cycling_to_work', 'travel_work_from_home',  
#              'vehicle_total', 
             'travel_total_to_work', 'travel_driving_to_work', 'travel_pt_to_work', 'travel_taxi_to_work', 'travel_cycle_to_work', 'travel_walk_to_work', 'travel_work_from_home', 
# education             
             'edu_total_pop', 
             'bachelor_male_25_34', 'master_phd_male_25_34', 'bachelor_male_35_44', 'master_phd_male_35_44', 'bachelor_male_45_64', 'master_phd_male_45_64',  'bachelor_male_65_over', 'master_phd_male_65_over',
             'bachelor_female_25_34', 'master_phd_female_25_34', 'bachelor_female_35_44', 'master_phd_female_35_44', 'bachelor_female_45_64', 'master_phd_female_45_64',  'bachelor_female_65_over', 'master_phd_female_65_over',
             'edu_total', 'edu_bachelor', 'edu_master', 'edu_phd',  
# income info (more complete)                       
             'inc_median_household', 'inc_per_capita', 
# employement
            'employment_total_labor', 'employment_employed', 'employment_unemployed', 
# properties                                       
             'housing_units_total', 'housing_units_occupied', 'housing_units_vacant',
             'rent_median', 
#              'rent_0_bedroom', 'rent_1_bedroom', 'rent_2_bedroom', 'rent_3_bedroom', 'rent_4_bedroom', 'rent_5_bedroom', 
#              'rent_built_2014', 'rent_built_2010', 'rent_built_2000', 'rent_built_1990', 'rent_built_1980', 'rent_built_1970', 'rent_built_1960', 'rent_built_1950', 'rent_built_1940', 'rent_built_1930',
             'property_value_total', 'property_value_median', 
# imputation
            'vehicle_total_imputed'
            ]

# %% [markdown]
# ## Collect data (MA and NH)

# %%
ma_county_list = ['003', '001', '023', '021', '019', '025', '007', '017', '005', '013', '009', '011', '027', '015']
nh_county_list = ['013', '001', '017', '005', '009', '015', '019', '011', '007', '003']

# %%
censusdata.geographies(censusdata.censusgeo([('state', '33'), ('county', '*')]), 'acs5', 2009)
# Out:
# {'Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'))),
#  'Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'))),
#  'Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'))),
#  'Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'))),
#  'Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'))),
#  'Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'))),
#  'Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'))),
#  'Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'))),
#  'Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'))),
#  'Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019')))}

# %%
# test the variable availability.
test_df = censusdata.download('acs5', 2013, censusdata.censusgeo([('state', '25'), ('county', '001'), ('block group', '*')]),
                                            var_list)
test_df.columns = var_names
pd.set_option('display.max_rows', 500)
print(np.sum(test_df.isna()))
pd.set_option('display.max_rows', 10)
# Out:
# pop_total                      0
# sex_total                      0
# sex_male                       0
# sex_female                     0
# age_median                     0
# households                     0
# race_total                     0
# race_white                     0
# race_black                     0
# race_native                    0
# race_asian                     0
# inc_total_pop                196
# inc_no_pop                   196
# inc_with_pop                 196
# inc_pop_10k                  196
# inc_pop_1k_15k               196
# inc_pop_15k_25k              196
# inc_pop_25k_35k              196
# inc_pop_35k_50k              196
# inc_pop_50k_65k              196
# inc_pop_65k_75k              196
# inc_pop_75k                  196
# inc_median_ind               196
# travel_total_to_work           0
# travel_driving_to_work         0
# travel_pt_to_work              0
# travel_taxi_to_work            0
# travel_cycle_to_work           0
# travel_walk_to_work            0
# travel_work_from_home          0
# edu_total_pop                196
# bachelor_male_25_34          196
# master_phd_male_25_34        196
# bachelor_male_35_44          196
# master_phd_male_35_44        196
# bachelor_male_45_64          196
# master_phd_male_45_64        196
# bachelor_male_65_over        196
# master_phd_male_65_over      196
# bachelor_female_25_34        196
# master_phd_female_25_34      196
# bachelor_female_35_44        196
# master_phd_female_35_44      196
# bachelor_female_45_64        196
# master_phd_female_45_64      196
# bachelor_female_65_over      196
# master_phd_female_65_over    196
# edu_total                      0
# edu_bachelor                   0
# edu_master                     0
# edu_phd                        0
# inc_median_household           0
# inc_per_capita                 0
# employment_total_labor         0
# employment_employed            0
# employment_unemployed          0
# housing_units_total            0
# housing_units_occupied         0
# housing_units_vacant           0
# rent_median                    0
# property_value_total           0
# property_value_median          0
# vehicle_total_imputed          0
# dtype: int64

# %%
pd.set_option('display.max_columns', 500)
test_df
# Out:
#                                                     pop_total  sex_total  \
# Block Group 5, Census Tract 3155, Middlesex Cou...       1527       1527
# Block Group 4, Census Tract 3883, Middlesex Cou...        888        888
# Block Group 3, Census Tract 3872.01, Middlesex ...        704        704
# Block Group 1, Census Tract 3872.02, Middlesex ...       1152       1152
# Block Group 3, Census Tract 3398.01, Middlesex ...       1019       1019
# ...                                                       ...        ...
# Block Group 3, Census Tract 3392, Middlesex Cou...       1073       1073
# Block Group 2, Census Tract 3392, Middlesex Cou...        852        852
# Block Group 6, Census Tract 3392, Middlesex Cou...        749        749
# Block Group 4, Census Tract 3392, Middlesex Cou...       1481       1481
# Block Group 3, Census Tract 3400, Middlesex Cou...        675        675
#
#                                                     sex_male  sex_female  \
# Block Group 5, Census Tract 3155, Middlesex Cou...       638         889
# Block Group 4, Census Tract 3883, Middlesex Cou...       518         370
# Block Group 3, Census Tract 3872.01, Middlesex ...       359         345
# Block Group 1, Census Tract 3872.02, Middlesex ...       573         579
# Block Group 3, Census Tract 3398.01, Middlesex ...       569         450
# ...                                                      ...         ...
# Block Group 3, Census Tract 3392, Middlesex Cou...       553         520
# Block Group 2, Census Tract 3392, Middlesex Cou...       414         438
# Block Group 6, Census Tract 3392, Middlesex Cou...       407         342
# Block Group 4, Census Tract 3392, Middlesex Cou...       652         829
# Block Group 3, Census Tract 3400, Middlesex Cou...       353         322
#
#                                                     age_median  households  \
# Block Group 5, Census Tract 3155, Middlesex Cou...        46.6         609
# Block Group 4, Census Tract 3883, Middlesex Cou...        23.7         186
# Block Group 3, Census Tract 3872.01, Middlesex ...        54.9         320
# Block Group 1, Census Tract 3872.02, Middlesex ...        44.8         397
# Block Group 3, Census Tract 3398.01, Middlesex ...        30.5         469
# ...                                                        ...         ...
# Block Group 3, Census Tract 3392, Middlesex Cou...        34.3         413
# Block Group 2, Census Tract 3392, Middlesex Cou...        32.9         260
# Block Group 6, Census Tract 3392, Middlesex Cou...        53.5         330
# Block Group 4, Census Tract 3392, Middlesex Cou...        52.2         545
...
# Block Group 3, Census Tract 3392, Middlesex Cou...                   324
# Block Group 2, Census Tract 3392, Middlesex Cou...                   217
# Block Group 6, Census Tract 3392, Middlesex Cou...                   249
# Block Group 4, Census Tract 3392, Middlesex Cou...                   419
# Block Group 3, Census Tract 3400, Middlesex Cou...                   192
#
#                                                     property_value_median  \
# Block Group 5, Census Tract 3155, Middlesex Cou...               275600.0
# Block Group 4, Census Tract 3883, Middlesex Cou...                    NaN
# Block Group 3, Census Tract 3872.01, Middlesex ...               382700.0
# Block Group 1, Census Tract 3872.02, Middlesex ...               340100.0
# Block Group 3, Census Tract 3398.01, Middlesex ...               404300.0
# ...                                                                   ...
# Block Group 3, Census Tract 3392, Middlesex Cou...               495500.0
# Block Group 2, Census Tract 3392, Middlesex Cou...               579400.0
# Block Group 6, Census Tract 3392, Middlesex Cou...               465900.0
# Block Group 4, Census Tract 3392, Middlesex Cou...               431800.0
# Block Group 3, Census Tract 3400, Middlesex Cou...               400000.0
#
#                                                     vehicle_total_imputed
# Block Group 5, Census Tract 3155, Middlesex Cou...                    742
# Block Group 4, Census Tract 3883, Middlesex Cou...                    387
# Block Group 3, Census Tract 3872.01, Middlesex ...                    362
# Block Group 1, Census Tract 3872.02, Middlesex ...                    629
# Block Group 3, Census Tract 3398.01, Middlesex ...                    623
# ...                                                                   ...
# Block Group 3, Census Tract 3392, Middlesex Cou...                    678
# Block Group 2, Census Tract 3392, Middlesex Cou...                    548
# Block Group 6, Census Tract 3392, Middlesex Cou...                    539
# Block Group 4, Census Tract 3392, Middlesex Cou...                    696
# Block Group 3, Census Tract 3400, Middlesex Cou...                    368
#
# [1133 rows x 79 columns]

# %%
pd.set_option('display.max_columns', 10)

# %%
# need ma_bg_2016, ma_bg_2018, nh_bg_2016, nh_bg_2018.
ma_bg_2009_dic = {}
nh_bg_2009_dic = {}
ma_bg_2013_dic = {}
nh_bg_2013_dic = {}
ma_bg_2016_dic = {}
ma_bg_2018_dic = {}
nh_bg_2016_dic = {}
nh_bg_2018_dic = {}

for ma_county_idx in ma_county_list:
    ma_bg_2013_dic[ma_county_idx] = censusdata.download('acs5', 2013,
                                                        censusdata.censusgeo([('state', '25'), ('county', ma_county_idx), ('block group', '*')]),
                                                        var_list)
#     ma_bg_2018_dic[ma_county_idx] = censusdata.download('acs5', 2018,
#                                                         censusdata.censusgeo([('state', '25'), ('county', ma_county_idx), ('block group', '*')]),
#                                                         var_list)

for nh_county_idx in nh_county_list:
    nh_bg_2013_dic[nh_county_idx] = censusdata.download('acs5', 2013,
                                                        censusdata.censusgeo([('state', '33'), ('county', nh_county_idx), ('block group', '*')]),
                                                        var_list)
#     nh_bg_2018_dic[nh_county_idx] = censusdata.download('acs5', 2018,
#                                                         censusdata.censusgeo([('state', '33'), ('county', nh_county_idx), ('block group', '*')]),
#                                                         var_list)

# %%
# process 2009
ma_bg_2013_df = pd.concat(ma_bg_2013_dic.values())
nh_bg_2013_df = pd.concat(nh_bg_2013_dic.values())

# replace the column names 
ma_bg_2013_df.columns = var_names
nh_bg_2013_df.columns = var_names

# add year
ma_bg_2013_df['year']=2013
nh_bg_2013_df['year']=2013

# add state
ma_bg_2013_df['state'] = 'MA'
nh_bg_2013_df['state'] = 'NH'

# concat the files
boston_metro_bg_2013_df = pd.concat([ma_bg_2013_df, nh_bg_2013_df], axis = 0)

# %%
# process 2016 and 2018
# concat the files. 
ma_bg_2016_df = pd.concat(ma_bg_2016_dic.values())
ma_bg_2018_df = pd.concat(ma_bg_2018_dic.values())
nh_bg_2016_df = pd.concat(nh_bg_2016_dic.values())
nh_bg_2018_df = pd.concat(nh_bg_2018_dic.values())

# replace the column names 
ma_bg_2016_df.columns = var_names
ma_bg_2018_df.columns = var_names
nh_bg_2016_df.columns = var_names
nh_bg_2018_df.columns = var_names

# add year
ma_bg_2016_df['year'] = 2016
ma_bg_2018_df['year'] = 2018
nh_bg_2016_df['year'] = 2016
nh_bg_2018_df['year'] = 2018

# add state
ma_bg_2016_df['state'] = 'MA'
ma_bg_2018_df['state'] = 'MA'
nh_bg_2016_df['state'] = 'NH'
nh_bg_2018_df['state'] = 'NH'

# concat the four files.
boston_metro_bg_2016_df = pd.concat([ma_bg_2016_df, nh_bg_2016_df], axis = 0)
boston_metro_bg_2018_df = pd.concat([ma_bg_2018_df, nh_bg_2018_df], axis = 0)

# %%
boston_metro_bg_2009_df.index[0]
# Out:
# censusgeo((('state', '25'), ('county', '003'), ('tract', '901100'), ('block group', '3')), 'Block Group 3, Census Tract 9011, Berkshire County, Massachusetts')

# %%
# add the FIPS info. Change the idx.
# boston_metro_bg_year_df = boston_metro_bg_2016_df
# boston_metro_bg_year_df = boston_metro_bg_2018_df

def add_fips(boston_metro_bg_year_df):
    state_fips=[]
    county_fips=[]
    tract_fips=[]
    bg_fips=[]
    full_bg_fips=[]

    for i in range(boston_metro_bg_year_df.shape[0]):
        state_fips.append(boston_metro_bg_year_df.index[i].params()[0][1])
        county_fips.append(boston_metro_bg_year_df.index[i].params()[1][1])
        tract_fips.append(boston_metro_bg_year_df.index[i].params()[2][1])
        bg_fips.append(boston_metro_bg_year_df.index[i].params()[3][1])
        full_bg_fips.append(boston_metro_bg_year_df.index[i].params()[0][1]+boston_metro_bg_year_df.index[i].params()[1][1]
                               +boston_metro_bg_year_df.index[i].params()[2][1]+boston_metro_bg_year_df.index[i].params()[3][1])

    boston_metro_bg_year_df['state_fips']=state_fips
    boston_metro_bg_year_df['county_fips']=county_fips
    boston_metro_bg_year_df['tract_fips']=tract_fips
    boston_metro_bg_year_df['bg_fips']=bg_fips
    boston_metro_bg_year_df['full_bg_fips']=full_bg_fips

    # reset index
    boston_metro_bg_year_df.reset_index(drop = True, inplace = True)
    return boston_metro_bg_year_df

# do both.
boston_metro_bg_2013_df_v1 = add_fips(boston_metro_bg_2013_df)
# boston_metro_bg_2018_df_v1 = add_fips(boston_metro_bg_2018_df)

# %%
boston_metro_bg_2009_df_v1.shape
# Out:
# (5924, 63)

# %%
boston_metro_bg_2018_df_v1
# Out:
#       pop_total  sex_total  sex_male  sex_female  age_median  ...  state_fips  \
# 0           976        976       458         518        28.9  ...          25
# 1          1053       1053       566         487        53.8  ...          25
# 2           464        464       143         321        57.1  ...          25
# 3          1322       1322       690         632        45.4  ...          25
# 4           500        500       239         261        44.6  ...          25
# ...         ...        ...       ...         ...         ...  ...         ...
# 5902        705        705       353         352        29.4  ...          33
# 5903        807        807       349         458        58.1  ...          33
# 5904        642        642       325         317        57.1  ...          33
# 5905        985        985       479         506        41.5  ...          33
# 5906       1220       1220       583         637        36.8  ...          33
#
#       county_fips  tract_fips  bg_fips  full_bg_fips
# 0             003      900200        5  250039002005
# 1             003      925100        7  250039251007
# 2             003      900900        5  250039009005
# 3             003      912100        7  250039121007
# 4             003      922100        4  250039221004
# ...           ...         ...      ...           ...
# 5902          003      955400        2  330039554002
# 5903          003      955400        1  330039554001
# 5904          003      955400        4  330039554004
# 5905          003      955400        5  330039554005
# 5906          003      955400        3  330039554003
#
# [5907 rows x 86 columns]

# %%
# describe.
pd.set_option('display.max_rows', 500)
print(np.sum(boston_metro_bg_2009_df_v1.isna()))
# print(np.sum(boston_metro_bg_2018_df_v1.isna()))
pd.set_option('display.max_rows', 10)
# Out:
# pop_total                       0
# sex_total                       0
# sex_male                        0
# sex_female                      0
# age_median                     20
# households                      0
# race_total                      0
# race_white                      0
# race_black                      0
# race_native                     0
# race_asian                      0
# inc_total_pop                5924
# inc_no_pop                   5924
# inc_with_pop                 5924
# inc_pop_10k                  5924
# inc_pop_1k_15k               5924
# inc_pop_15k_25k              5924
# inc_pop_25k_35k              5924
# inc_pop_35k_50k              5924
# inc_pop_50k_65k              5924
# inc_pop_65k_75k              5924
# inc_pop_75k                  5924
# inc_median_ind               5924
# travel_total_to_work            0
# travel_driving_to_work          0
# travel_pt_to_work               0
# travel_taxi_to_work             0
# travel_cycle_to_work            0
# travel_walk_to_work             0
# travel_work_from_home           0
# edu_total_pop                5924
# bachelor_male_25_34          5924
# master_phd_male_25_34        5924
# bachelor_male_35_44          5924
# master_phd_male_35_44        5924
# bachelor_male_45_64          5924
# master_phd_male_45_64        5924
# bachelor_male_65_over        5924
# master_phd_male_65_over      5924
# bachelor_female_25_34        5924
# master_phd_female_25_34      5924
# bachelor_female_35_44        5924
# master_phd_female_35_44      5924
# bachelor_female_45_64        5924
# master_phd_female_45_64      5924
# bachelor_female_65_over      5924
# master_phd_female_65_over    5924
# inc_median_household           29
# inc_per_capita                 20
# housing_units_total             0
# housing_units_occupied          0
# housing_units_vacant            0
# rent_median                  1023
# property_value_total            0
# property_value_median         170
# vehicle_total_imputed           0
# year                            0
# state                           0
# state_fips                      0
# county_fips                     0
# tract_fips                      0
# bg_fips                         0
# full_bg_fips                    0
# dtype: int64

# %% [markdown]
# ## Create new vars, drop nans, and light imputation.

# %%
# drop nans
boston_metro_bg_2013_df_v2 = boston_metro_bg_2013_df_v1.dropna(axis = 1, thresh = boston_metro_bg_2013_df_v1.shape[0] - 1500)
# boston_metro_bg_2018_df_v2 = boston_metro_bg_2018_df_v1.dropna(axis = 1, thresh = boston_metro_bg_2018_df_v1.shape[0] - 100)

# %%
boston_metro_bg_2013_df_v2.columns
# Out:
# Index(['pop_total', 'sex_total', 'sex_male', 'sex_female', 'age_median',
#        'households', 'race_total', 'race_white', 'race_black', 'race_native',
#        'race_asian', 'travel_total_to_work', 'travel_driving_to_work',
#        'travel_pt_to_work', 'travel_taxi_to_work', 'travel_cycle_to_work',
#        'travel_walk_to_work', 'travel_work_from_home', 'edu_total',
#        'edu_bachelor', 'edu_master', 'edu_phd', 'inc_median_household',
#        'inc_per_capita', 'employment_total_labor', 'employment_employed',
#        'employment_unemployed', 'housing_units_total',
#        'housing_units_occupied', 'housing_units_vacant', 'rent_median',
#        'property_value_total', 'property_value_median',
#        'vehicle_total_imputed', 'year', 'state', 'state_fips', 'county_fips',
#        'tract_fips', 'bg_fips', 'full_bg_fips'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 500)
print(np.sum(boston_metro_bg_2013_df_v2.isna()))
# print(np.sum(boston_metro_bg_2018_df_v2.isna()))
pd.set_option('display.max_rows', 10)
# Out:
# pop_total                 0
# sex_total                 0
# sex_male                  0
# sex_female                0
# age_median                0
# households                0
# race_total                0
# race_white                0
# race_black                0
# race_native               0
# race_asian                0
# travel_total_to_work      0
# travel_driving_to_work    0
# travel_pt_to_work         0
# travel_taxi_to_work       0
# travel_cycle_to_work      0
# travel_walk_to_work       0
# travel_work_from_home     0
# edu_total                 0
# edu_bachelor              0
# edu_master                0
# edu_phd                   0
# inc_median_household      0
# inc_per_capita            2
# employment_total_labor    0
# employment_employed       0
# employment_unemployed     0
# housing_units_total       0
# housing_units_occupied    0
# housing_units_vacant      0
# rent_median               0
# property_value_total      0
# property_value_median     0
# vehicle_total_imputed     0
# year                      0
# state                     0
# state_fips                0
# county_fips               0
# tract_fips                0
# bg_fips                   0
# full_bg_fips              0
# dtype: int64

# %%
pd.set_option('display.max_columns', 500)
boston_metro_bg_2016_df_v2.head(15)
# Out:
#     pop_total  sex_total  sex_male  sex_female  age_median  households  \
# 0        1831       1831       862         969        39.7         799
# 1         819        819       234         585        20.0          64
# 2         769        769       340         429        33.0         308
# 3        1025       1025       580         445        40.7         341
# 4         933        933       446         487        51.0         423
# ..        ...        ...       ...         ...         ...         ...
# 10        430        430       207         223        49.0         192
# 11        689        689       393         296        37.2         346
# 12       1032       1032       495         537        54.1         484
# 13        731        731       372         359        51.7         377
# 14        826        826       396         430        47.3         334
#
#     race_total  race_white  race_black  race_native  race_asian  \
# 0         1831        1609          21           28          13
# 1          819         711          83            0           0
# 2          769         567         117            5           0
# 3         1025         886          50            0           0
# 4          933         734          31            0           0
# ..         ...         ...         ...          ...         ...
# 10         430         367          11            0           0
# 11         689         561          29            0          29
# 12        1032        1032           0            0           0
# 13         731         682          29            0           0
# 14         826         786           8            2           3
#
#     travel_total_to_work  travel_driving_to_work  travel_pt_to_work  \
# 0                    960                     758                 39
# 1                    342                      85                 17
# 2                    358                     307                  0
# 3                    368                     340                  0
# 4                    561                     396                 18
# ..                   ...                     ...                ...
# 10                   259                     250                  0
# 11                   383                     343                  0
# 12                   473                     419                 28
# 13                   387                     301                 23
# 14                   475                     462                  0
#
#     travel_taxi_to_work  travel_cycle_to_work  travel_walk_to_work  \
# 0                     0                     0                  146
# 1                     0                     0                  205
# 2                     0                     0                   42
# 3                     0                     0                    0
# 4                     0                     0                  130
# ..                  ...                   ...                  ...
# 10                    0                     0                    9
# 11                    0                     0                   12
# 12                    0                     0                    0
# 13                    0                     0                   20
# 14                    0                     0                    0
#
#     travel_work_from_home  edu_total  edu_bachelor  edu_master  edu_phd  \
# 0                      17       1146           125         122       22
# 1                      35        100            28           8        0
# 2                       0        529            19           9        0
# 3                      28        629            46          79       13
# 4                      17        800            70         131       13
# ..                    ...        ...           ...         ...      ...
# 10                      0        380            78          17        0
# 11                     28        469            51          16        9
# 12                     17        819            99          65       10
# 13                     43        605           139          61        0
# 14                      7        628           114          26        5
#
#     inc_median_household  inc_per_capita  employment_total_labor  \
# 0                  24938         26565.0                    1548
# 1                  39167          5356.0                     759
# 2                  43056         17924.0                     611
# 3                  50662         25132.0                     744
# 4                  55208         39529.0                     813
# ..                   ...             ...                     ...
# 10                 47391         25997.0                     424
# 11                 28929         20430.0                     550
# 12                 52440         31309.0                     918
# 13                 39063         33056.0                     679
# 14                 67250         30782.0                     691
#
#     employment_employed  employment_unemployed  housing_units_total  \
# 0                  1029                    519                 1025
# 1                   464                    295                   64
# 2                   411                    200                  340
# 3                   418                    326                  437
# 4                   607                    206                  442
# ..                  ...                    ...                  ...
# 10                  295                    129                  192
# 11                  426                    124                  362
# 12                  509                    409                  566
# 13                  411                    268                  496
# 14                  517                    174                  394
#
#     housing_units_occupied  housing_units_vacant  rent_median  \
# 0                      799                   226          690
# 1                       64                     0   -666666666
# 2                      308                    32         1063
# 3                      341                    96   -666666666
# 4                      423                    19          774
# ..                     ...                   ...          ...
# 10                     192                     0   -666666666
# 11                     346                    16          866
# 12                     484                    82          734
# 13                     377                   119          746
# 14                     334                    60   -666666666
#
#     property_value_total  property_value_median  vehicle_total_imputed  year  \
# 0                    346                 168100                    960  2016
# 1                     56                 625000                    342  2016
# 2                    126                 134100                    358  2016
# 3                    283                 283200                    368  2016
# 4                    231                 265900                    561  2016
# ..                   ...                    ...                    ...   ...
# 10                   175                 133100                    259  2016
# 11                   173                 142700                    383  2016
# 12                   398                 194900                    473  2016
# 13                   173                 331600                    387  2016
# 14                   307                 190300                    475  2016
#
#    state state_fips county_fips tract_fips bg_fips  full_bg_fips
# 0     MA         25         003     921300       2  250039213002
# 1     MA         25         003     921300       4  250039213004
# 2     MA         25         003     900200       5  250039002005
# 3     MA         25         003     925100       7  250039251007
# 4     MA         25         003     925100       3  250039251003
# ..   ...        ...         ...        ...     ...           ...
# 10    MA         25         003     900400       3  250039004003
# 11    MA         25         003     900600       5  250039006005
# 12    MA         25         003     923100       2  250039231002
# 13    MA         25         003     924100       2  250039241002
# 14    MA         25         003     931400       2  250039314002
#
# [15 rows x 41 columns]

# %%
boston_metro_bg_2013_df_v2.describe()
# plt.hist(boston_metro_bg_2016_df_v2.property_value_median)
# Out:
#          pop_total    sex_total     sex_male   sex_female    age_median  \
# count  5907.000000  5907.000000  5907.000000  5907.000000  5.907000e+03
# mean   1341.498053  1341.498053   651.533435   689.964618 -2.821471e+06
# std     644.974097   644.974097   329.359536   338.609794  4.328237e+07
# min       0.000000     0.000000     0.000000     0.000000 -6.666667e+08
# 25%     875.000000   875.000000   415.000000   449.000000  3.460000e+01
# 50%    1208.000000  1208.000000   584.000000   620.000000  4.100000e+01
# 75%    1673.000000  1673.000000   823.000000   859.500000  4.610000e+01
# max    7846.000000  7846.000000  3744.000000  4102.000000  8.440000e+01
#
#        households   race_total   race_white   race_black  race_native  ...  \
# count  5907.00000  5907.000000  5907.000000  5907.000000  5907.000000  ...
# mean    516.06433  1341.498053  1110.369392    79.718639     2.631454  ...
# std     238.99785   644.974097   623.274575   176.781608    11.714783  ...
# min       0.00000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     344.00000   875.000000   678.000000     0.000000     0.000000  ...
# 50%     471.00000  1208.000000   988.000000    13.000000     0.000000  ...
# 75%     646.00000  1673.000000  1443.500000    73.000000     0.000000  ...
# max    2656.00000  7846.000000  6275.000000  2746.000000   259.000000  ...
#
#        employment_employed  employment_unemployed  housing_units_total  \
# count          5907.000000            5907.000000          5907.000000
# mean            741.527340             349.674454           579.609446
# std             371.081628             228.587891           276.877168
# min               0.000000               0.000000             0.000000
# 25%             473.000000             211.000000           381.000000
# 50%             669.000000             304.000000           528.000000
# 75%             944.000000             433.000000           728.000000
# max            3162.000000            4638.000000          3194.000000
#
#        housing_units_occupied  housing_units_vacant   rent_median  \
# count              5907.00000           5907.000000  5.907000e+03
# mean                516.06433             63.545116 -1.409618e+08
# std                 238.99785            129.386865  2.722452e+08
# min                   0.00000              0.000000 -6.666667e+08
# 25%                 344.00000              0.000000  4.620000e+02
# 50%                 471.00000             33.000000  9.460000e+02
# 75%                 646.00000             69.000000  1.232000e+03
# max                2656.00000           2829.000000  2.001000e+03
#
#        property_value_total  property_value_median  vehicle_total_imputed  \
# count           5907.000000           5.907000e+03            5907.000000
# mean             331.036397          -2.382823e+07             662.657017
# std              216.075886           1.246451e+08             340.212410
# min                0.000000          -6.666667e+08               0.000000
# 25%              174.000000           2.182500e+05             416.000000
# 50%              287.000000           2.924000e+05             593.000000
# 75%              451.500000           3.856000e+05             846.000000
# max             1436.000000           1.000001e+06            2463.000000
#
#          year
# count  5907.0
# mean   2013.0
# std       0.0
# min    2013.0
# 25%    2013.0
# 50%    2013.0
# 75%    2013.0
# max    2013.0
#
# [8 rows x 35 columns]

# %%
# print the counts.
# epsilon = -0.00001
epsilon = 0.00001
print("Count of zero population", np.sum(boston_metro_bg_2016_df_v2.pop_total < epsilon))
print("Count of zero median household income", np.sum(boston_metro_bg_2016_df_v2.inc_median_household < epsilon))
print("Count of zero travels to work", np.sum(boston_metro_bg_2016_df_v2.travel_total_to_work < epsilon))
print("Count of zero income per capita", np.sum(boston_metro_bg_2016_df_v2.inc_per_capita < epsilon))
print("Count of zero (and NA) median rent", np.sum(boston_metro_bg_2016_df_v2.rent_median < epsilon))
print("Count of zero (and NA) total property values", np.sum(boston_metro_bg_2016_df_v2.property_value_total < epsilon))
print("Count of zero (and NA) median property values", np.sum(boston_metro_bg_2016_df_v2.property_value_median < epsilon))

# np.sum(boston_metro_bg_2016_df_v2.year == 0.0)
# Out:
# Count of zero population 22
# Count of zero median household income 213
# Count of zero travels to work 26
# Count of zero income per capita 22
# Count of zero (and NA) median rent 1443
# Count of zero (and NA) total property values 92
# Count of zero (and NA) median property values 295

# %%
pd.set_option('display.max_rows', 500)
boston_metro_bg_2016_df_v2.dtypes
# Out:
# pop_total                   int64
# sex_total                   int64
# sex_male                    int64
# sex_female                  int64
# age_median                float64
# households                  int64
# race_total                  int64
# race_white                  int64
# race_black                  int64
# race_native                 int64
# race_asian                  int64
# travel_total_to_work        int64
# travel_driving_to_work      int64
# travel_pt_to_work           int64
# travel_taxi_to_work         int64
# travel_cycle_to_work        int64
# travel_walk_to_work         int64
# travel_work_from_home       int64
# edu_total                   int64
# edu_bachelor                int64
# edu_master                  int64
# edu_phd                     int64
# inc_median_household        int64
# inc_per_capita            float64
# employment_total_labor      int64
# employment_employed         int64
# employment_unemployed       int64
# housing_units_total         int64
# housing_units_occupied      int64
# housing_units_vacant        int64
# rent_median                 int64
# property_value_total        int64
# property_value_median       int64
# vehicle_total_imputed       int64
# year                        int64
# state                      object
# state_fips                 object
# county_fips                object
# tract_fips                 object
# bg_fips                    object
# full_bg_fips               object
# dtype: object

# %%
# drop bgs with zero population. 
# wait. then I have to be sure that dropped bgs from the two years are the same...
boston_metro_bg_2013_df_v2 = boston_metro_bg_2013_df_v2.loc[boston_metro_bg_2013_df_v2.pop_total > 0.0001, :].reset_index(drop = True)
# boston_metro_bg_2016_df_v2 = boston_metro_bg_2016_df_v2.loc[boston_metro_bg_2016_df_v2.pop_total > 0.0001, :].reset_index(drop = True)
# boston_metro_bg_2018_df_v2 = boston_metro_bg_2018_df_v2.loc[boston_metro_bg_2018_df_v2.pop_total > 0.0001, :].reset_index(drop = True)

# replace the super large negative values (NaN notations) by real NA.
var_list_to_replace_negative_values = ['age_median', 'inc_median_household', 'rent_median', 'property_value_median']
for var in var_list_to_replace_negative_values:
    boston_metro_bg_2013_df_v2.loc[boston_metro_bg_2013_df_v2[var] < -100, var] = np.nan # 2009
#     boston_metro_bg_2016_df_v2.loc[boston_metro_bg_2016_df_v2[var] < -100, var] = np.nan # 2016
#     boston_metro_bg_2018_df_v2.loc[boston_metro_bg_2018_df_v2[var] < -100, var] = np.nan # 2018

# impute the NAs with KNN.
from sklearn.impute import KNNImputer
imp = KNNImputer(missing_values=np.nan, n_neighbors=5)

imputing_vars = list(boston_metro_bg_2013_df_v2.dtypes[boston_metro_bg_2013_df_v2.dtypes != 'object'].index)
# imputing 2009, 2016, and 2018 data
imp.fit(boston_metro_bg_2013_df_v2[imputing_vars])
boston_metro_bg_2013_df_v2[imputing_vars] = imp.transform(boston_metro_bg_2013_df_v2[imputing_vars])

# %%
boston_metro_bg_2009_df_v2.columns
# Out:
# Index(['pop_total', 'sex_total', 'sex_male', 'sex_female', 'age_median',
#        'households', 'race_total', 'race_white', 'race_black', 'race_native',
#        'race_asian', 'travel_total_to_work', 'travel_driving_to_work',
#        'travel_pt_to_work', 'travel_taxi_to_work', 'travel_cycle_to_work',
#        'travel_walk_to_work', 'travel_work_from_home', 'inc_median_household',
#        'inc_per_capita', 'housing_units_total', 'housing_units_occupied',
#        'housing_units_vacant', 'rent_median', 'property_value_total',
#        'property_value_median', 'vehicle_total_imputed', 'year', 'state',
#        'state_fips', 'county_fips', 'tract_fips', 'bg_fips', 'full_bg_fips',
#        'household_size_avg', 'sex_male_ratio', 'race_white_ratio',
#        'race_black_ratio', 'race_native_ratio', 'race_asian_ratio',
#        'travel_driving_ratio', 'travel_pt_ratio', 'travel_taxi_ratio',
#        'travel_cycle_ratio', 'travel_walk_ratio', 'travel_work_home_ratio',
#        'vehicle_per_capita', 'vehicle_per_household'],
#       dtype='object')

# %%
# lift the nominator variables by one to avoid weird inf and nan...
var_list_to_be_lifted_by_one = ['pop_total', 'sex_total', 'households', 'race_total',
                                'travel_total_to_work', 'edu_total', 'housing_units_total', 'property_value_total', 
                                'vehicle_total_imputed']

for var in var_list_to_be_lifted_by_one:
    for df in [boston_metro_bg_2013_df_v2]: # boston_metro_bg_2009_df_v2, boston_metro_bg_2016_df_v2, boston_metro_bg_2018_df_v2
        try:
            df.loc[df[var] == 0.0, var] += 1.0
        except KeyError:
            pass

# %%
# create new vars.
# household_size_avg, 
# sex_male_ratio, race_white_ratio, race_black_ratio, race_native_ratio, race_asian_ratio, 
# travel_driving_ratio, travel_pt_ratio, travel_taxi_ratio, travel_cycle_ratio, travel_walk_ratio, travel_work_home_ratio
# edu_bachelor_ratio, edu_master_ratio, edu_phd_ratio
# employment_unemployed_ratio
# vehicle_per_capita, vehicle_per_household, 
# again, 2009, 2016, and 2018 have different var list. It creates trouble in data processing. 

for df in [boston_metro_bg_2013_df_v2]:
    df['household_size_avg'] = df['pop_total']/df['households']
    df['sex_male_ratio'] = df['sex_male']/df['sex_total']
    df['race_white_ratio'] = df['race_white']/df['race_total']
    df['race_black_ratio'] = df['race_black']/df['race_total']
    df['race_native_ratio'] = df['race_native']/df['race_total']
    df['race_asian_ratio'] = df['race_asian']/df['race_total']
    df['travel_driving_ratio'] = df['travel_driving_to_work']/df['travel_total_to_work']
    df['travel_pt_ratio'] = df['travel_pt_to_work']/df['travel_total_to_work']
    df['travel_taxi_ratio'] = df['travel_taxi_to_work']/df['travel_total_to_work']
    df['travel_cycle_ratio'] = df['travel_cycle_to_work']/df['travel_total_to_work']
    df['travel_walk_ratio'] = df['travel_walk_to_work']/df['travel_total_to_work']
    df['travel_work_home_ratio'] = df['travel_work_from_home']/df['travel_total_to_work']
    df['edu_bachelor_ratio'] = df['edu_bachelor']/df['edu_total']
    df['edu_master_ratio'] = df['edu_master']/df['edu_total']
    df['edu_phd_ratio'] = df['edu_phd']/df['edu_total']
    df['employment_unemployed_ratio'] = df['employment_unemployed']/df['employment_total_labor']
    df['vehicle_per_capita'] = df['vehicle_total_imputed']/df['pop_total']
    df['vehicle_per_household'] = df['vehicle_total_imputed']/df['households']

# for df in [boston_metro_bg_2016_df_v2, boston_metro_bg_2018_df_v2]:
#     df['household_size_avg'] = df['pop_total']/df['households']
#     df['sex_male_ratio'] = df['sex_male']/df['sex_total']
#     df['race_white_ratio'] = df['race_white']/df['race_total']
#     df['race_black_ratio'] = df['race_black']/df['race_total']
#     df['race_native_ratio'] = df['race_native']/df['race_total']
#     df['race_asian_ratio'] = df['race_asian']/df['race_total']
#     df['travel_driving_ratio'] = df['travel_driving_to_work']/df['travel_total_to_work']
#     df['travel_pt_ratio'] = df['travel_pt_to_work']/df['travel_total_to_work']
#     df['travel_taxi_ratio'] = df['travel_taxi_to_work']/df['travel_total_to_work']
#     df['travel_cycle_ratio'] = df['travel_cycle_to_work']/df['travel_total_to_work']
#     df['travel_walk_ratio'] = df['travel_walk_to_work']/df['travel_total_to_work']
#     df['travel_work_home_ratio'] = df['travel_work_from_home']/df['travel_total_to_work']
#     df['edu_bachelor_ratio'] = df['edu_bachelor']/df['edu_total']
#     df['edu_master_ratio'] = df['edu_master']/df['edu_total']
#     df['edu_phd_ratio'] = df['edu_phd']/df['edu_total']
#     df['employment_unemployed_ratio'] = df['employment_unemployed']/df['employment_total_labor']
#     df['vehicle_per_capita'] = df['vehicle_total_imputed']/df['pop_total']
#     df['vehicle_per_household'] = df['vehicle_total_imputed']/df['households']

# %%
print(np.sum(boston_metro_bg_2013_df_v2.isna()))
# print(np.sum(boston_metro_bg_2018_df_v2.isna()))
# Out:
# pop_total                      0
# sex_total                      0
# sex_male                       0
# sex_female                     0
# age_median                     0
#                               ..
# edu_master_ratio               0
# edu_phd_ratio                  0
# employment_unemployed_ratio    0
# vehicle_per_capita             0
# vehicle_per_household          0
# Length: 59, dtype: int64

# %%
print(boston_metro_bg_2009_df_v2.shape[0])
# Out:
# 5904

# %%
# check whether the two numbers are the same.
print(boston_metro_bg_2016_df_v2.shape[0])
print(len(set(boston_metro_bg_2016_df_v2.index).intersection(set(boston_metro_bg_2018_df_v2.index))))
# Out:
# 5885
# 5885

# %% [markdown]
# ## Save

# %%
with open('../data/01_raw/boston_metro_bg_2016_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_bg_2016_df_v2, f)
    
with open('../data/01_raw/boston_metro_bg_2018_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_bg_2018_df_v2, f)

# %%
with open('../data/01_raw/boston_metro_bg_2009_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_bg_2009_df_v2, f)

# %%
with open('../data/01_raw/boston_metro_bg_2013_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_bg_2013_df_v2, f)
