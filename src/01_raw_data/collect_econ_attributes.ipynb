# %% [markdown]
# # Collect econ attributes for MA, NH, FL, and IL in 2016 and 2018 - Census Tracts
#
# - Two time points: ACS 2016 5y and ACS 2018 5y.
# - Output six files: Boston metro, florida, and illinois (2016, 2018)
# - Spatial unit: census tracts.

# %%
import pandas as pd
import censusdata # to download ACS data
import copy
import numpy as np
import matplotlib.pyplot as plt
import pickle
# Out:
# Bad key text.latex.unicode in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 112 ('text.latex.unicode : False # use "ucs" and "inputenc" LaTeX packages for handling')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key text.latex.preview in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 125 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 157 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 420 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 423 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key pgf.debug in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 444 ('pgf.debug           : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 475 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 476 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 493 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 504 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /home/jtl/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 506 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ## Check Information & Setup

# %%
censusdata.printtable(censusdata.censustable('acs5', 2016, 'B01002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B01002_001E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Total                          | float
# B01002_002E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Male                           | float
# B01002_003E  | MEDIAN AGE BY SEX              | !! !! Estimate Median age Female                         | float
# -------------------------------------------------------------------------------------------------------------------

# %%
# define variable list
# Include population, sex, age, race, income, travel, education, and properties.
# in 2009, the rows of B15003, B23035, B25031, B25111 did not exist. These rows exist in 2016 and 2018.

var_list = [
# population        
            'B01003_001E', 
            'B01001_001E', 'B01001_002E', 'B01001_026E', 
            'B01002_001E',
# households
            'B11001_001E',
# race
            'B02001_001E', 'B02001_002E', 'B02001_003E', 'B02001_004E', 'B02001_005E', 
# income info (a lot of NAs)    
            'B06010_001E', 'B06010_002E', 'B06010_003E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E', 'B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
            'B06011_001E',      
# travel
#             'B08101_001E', 'B08101_009E', 'B08101_017E', 'B08101_025E', 'B08101_033E', 'B08101_041E', 'B08101_049E', 
#             'B08015_001E', 
            'B08301_001E', 'B08301_002E', 'B08301_010E', 'B08301_016E', 'B08301_018E', 'B08301_019E', 'B08301_021E', 
# education                         
            'B15001_001E',
            'B15001_017E', 'B15001_018E', 'B15001_025E', 'B15001_026E', 'B15001_033E', 'B15001_034E', 'B15001_041E', 'B15001_042E', 
            'B15001_058E', 'B15001_059E', 'B15001_066E', 'B15001_067E', 'B15001_074E', 'B15001_075E', 'B15001_082E', 'B15001_083E',
            'B15003_001E', 'B15003_022E', 'B15003_023E', 'B15003_025E', 
# income info (more complete)                       
            'B19013_001E', 'B19301_001E', 
# employement
            'B23025_001E', 'B23025_002E', 'B23025_007E', 
# properties            
            'B25002_001E', 'B25002_002E', 'B25002_003E',             
            'B25064_001E', 
#             'B25031_002E', 'B25031_003E', 'B25031_004E', 'B25031_005E', 'B25031_006E', 'B25031_007E', 
#             'B25111_002E', 'B25111_003E', 'B25111_004E', 'B25111_005E', 'B25111_006E', 'B25111_007E', 'B25111_008E', 'B25111_009E', 'B25111_010E', 'B25111_011E',
            'B25075_001E', 'B25077_001E',
# imputation
            'B99082_001E'
           ]

var_names = [
# population
             'pop_total', 
             'sex_total', 'sex_male', 'sex_female',
             'age_median',
# hosueholds
             'households',
# race             
             'race_total', 'race_white', 'race_black', 'race_native', 'race_asian',
# income info (a lot of NAs)
             'inc_total_pop', 'inc_no_pop', 'inc_with_pop', 'inc_pop_10k', 'inc_pop_1k_15k', 'inc_pop_15k_25k', 'inc_pop_25k_35k', 'inc_pop_35k_50k', 'inc_pop_50k_65k', 'inc_pop_65k_75k', 'inc_pop_75k',
             'inc_median_ind', 
# travel
#              'travel_total_to_work', 'travel_single_driving_to_work', 'travel_carpool_to_work', 'travel_public_transit_to_work', 'travel_walking_to_work', 'travel_cycling_to_work', 'travel_work_from_home',  
#              'vehicle_total', 
             'travel_total_to_work', 'travel_driving_to_work', 'travel_pt_to_work', 'travel_taxi_to_work', 'travel_cycle_to_work', 'travel_walk_to_work', 'travel_work_from_home', 
# education             
             'edu_total_pop', 
             'bachelor_male_25_34', 'master_phd_male_25_34', 'bachelor_male_35_44', 'master_phd_male_35_44', 'bachelor_male_45_64', 'master_phd_male_45_64',  'bachelor_male_65_over', 'master_phd_male_65_over',
             'bachelor_female_25_34', 'master_phd_female_25_34', 'bachelor_female_35_44', 'master_phd_female_35_44', 'bachelor_female_45_64', 'master_phd_female_45_64',  'bachelor_female_65_over', 'master_phd_female_65_over',
             'edu_total', 'edu_bachelor', 'edu_master', 'edu_phd',  
# income info (more complete)                       
             'inc_median_household', 'inc_per_capita', 
# employement
            'employment_total_labor', 'employment_employed', 'employment_unemployed', 
# properties                                       
             'housing_units_total', 'housing_units_occupied', 'housing_units_vacant',
             'rent_median', 
#              'rent_0_bedroom', 'rent_1_bedroom', 'rent_2_bedroom', 'rent_3_bedroom', 'rent_4_bedroom', 'rent_5_bedroom', 
#              'rent_built_2014', 'rent_built_2010', 'rent_built_2000', 'rent_built_1990', 'rent_built_1980', 'rent_built_1970', 'rent_built_1960', 'rent_built_1950', 'rent_built_1940', 'rent_built_1930',
             'property_value_total', 'property_value_median', 
# imputation
            'vehicle_total_imputed'
            ]

# %% [markdown]
# ## Download data (MA, NH, FL, IL; 2016 and 2018)

# %%
ma_county_list = ['003', '001', '023', '021', '019', '025', '007', '017', '005', '013', '009', '011', '027', '015']
nh_county_list = ['013', '001', '017', '005', '009', '015', '019', '011', '007', '003']

# %%
censusdata.geographies(censusdata.censusgeo([('state', '33'), ('tract', '*')]), 'acs5', 2016)
# Out:
# {'Census Tract 1.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000102'))),
#  'Census Tract 14, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001400'))),
#  'Census Tract 106, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010600'))),
#  'Census Tract 114.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011402'))),
#  'Census Tract 121, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '012100'))),
#  'Census Tract 131, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '013100'))),
#  'Census Tract 142.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '014201'))),
#  'Census Tract 161, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '016100'))),
#  'Census Tract 240, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '024000'))),
#  'Census Tract 195.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '019502'))),
#  'Census Tract 1003.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '100301'))),
#  'Census Tract 1021, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '102100'))),
#  'Census Tract 710, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '071000'))),
#  'Census Tract 1003.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '100302'))),
#  'Census Tract 1011, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '101100'))),
#  'Census Tract 1061.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '106101'))),
#  'Census Tract 1004, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '100400'))),
#  'Census Tract 540, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '054000'))),
#  'Census Tract 697, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '069700'))),
#  'Census Tract 36.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003601'))),
#  'Census Tract 650.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '065001'))),
#  'Census Tract 9654, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965400'))),
#  'Census Tract 9659, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965900'))),
#  'Census Tract 9660, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966000'))),
#  'Census Tract 9665, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966500'))),
#  'Census Tract 9657, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965700'))),
#  'Census Tract 9651, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965100'))),
#  'Census Tract 9653, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965300'))),
#  'Census Tract 813, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081300'))),
#  'Census Tract 843, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084300'))),
#  'Census Tract 830.02, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '083002'))),
#  'Census Tract 820, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '082000'))),
#  'Census Tract 802.02, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '080202'))),
#  'Census Tract 830.01, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '083001'))),
#  'Census Tract 811, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081100'))),
#  'Census Tract 814, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081400'))),
#  'Census Tract 850, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '085000'))),
#  'Census Tract 9508, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950800'))),
#  'Census Tract 9510, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '951000'))),
#  'Census Tract 9503, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950300'))),
#  'Census Tract 9507, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950700'))),
#  'Census Tract 9509, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950900'))),
#  'Census Tract 9501, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950100'))),
#  'Census Tract 9505, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950500'))),
#  'Census Tract 9506, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950600'))),
#  'Census Tract 9511, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '951100'))),
#  'Census Tract 9502, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950200'))),
#  'Census Tract 9504, Coos County, New Hampshire': censusgeo((('state', '33'), ('county', '007'), ('tract', '950400'))),
#  'Census Tract 9553, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955300'))),
#  'Census Tract 9560, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '956000'))),
#  'Census Tract 9555, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955500'))),
#  'Census Tract 9558, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955800'))),
#  'Census Tract 9613, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961300'))),
#  'Census Tract 9616.02, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961602'))),
#  'Census Tract 9602, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960200'))),
#  'Census Tract 9603, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960300'))),
#  'Census Tract 9606, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960600'))),
#  'Census Tract 9607, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960700'))),
#  'Census Tract 9608, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960800'))),
#  'Census Tract 9612, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961200'))),
#  'Census Tract 9616.01, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961601'))),
#  'Census Tract 9614, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961400'))),
#  'Census Tract 9610, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961000'))),
#  'Census Tract 1051, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '105100'))),
#  'Census Tract 520, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '052000'))),
#  'Census Tract 550.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '055002'))),
#  'Census Tract 610.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '061001'))),
#  'Census Tract 625, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '062500'))),
#  'Census Tract 33.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003302'))),
#  'Census Tract 2002, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '200200'))),
#  'Census Tract 1.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000101'))),
#  'Census Tract 8, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000800'))),
#  'Census Tract 10, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001000'))),
#  'Census Tract 16, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001600'))),
#  'Census Tract 19, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001900'))),
#  'Census Tract 23, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002300'))),
#  'Census Tract 29.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002901'))),
#  'Census Tract 29.03, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002903'))),
#  'Census Tract 103.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010302'))),
#  'Census Tract 123, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '012300'))),
#  'Census Tract 162.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '016202'))),
#  'Census Tract 180, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '018000'))),
#  'Census Tract 220, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '022000'))),
#  'Census Tract 225, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '022500'))),
#  'Census Tract 21, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002100'))),
#  'Census Tract 142.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '014202'))),
#  'Census Tract 103.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010301'))),
#  'Census Tract 151, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '015100'))),
#  'Census Tract 101, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010100'))),
#  'Census Tract 141, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '014100'))),
#  'Census Tract 801, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '080100'))),
#  'Census Tract 812, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081200'))),
#  'Census Tract 846, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084600'))),
#  'Census Tract 860, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '086000'))),
#  'Census Tract 842, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084200'))),
#  'Census Tract 845, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084500'))),
#  'Census Tract 870, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '087000'))),
#  'Census Tract 880, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '088000'))),
#  'Census Tract 841, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084100'))),
#  'Census Tract 805, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '080500'))),
#  'Census Tract 815, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081500'))),
#  'Census Tract 816, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '081600'))),
#  'Census Tract 844, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '084400'))),
#  'Census Tract 9559, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955900'))),
#  'Census Tract 9564, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '956400'))),
#  'Census Tract 9561, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '956100'))),
#  'Census Tract 9556, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955600'))),
#  'Census Tract 9551, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955100'))),
#  'Census Tract 9563, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '956300'))),
#  'Census Tract 9554, Carroll County, New Hampshire': censusgeo((('state', '33'), ('county', '003'), ('tract', '955400'))),
#  'Census Tract 9656, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965600'))),
#  'Census Tract 9652, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965200'))),
#  'Census Tract 9655.98, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965598'))),
#  'Census Tract 9658, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '965800'))),
#  'Census Tract 9661, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966100'))),
#  'Census Tract 9662, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966200'))),
#  'Census Tract 9759.02, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975902'))),
#  'Census Tract 9754, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975400'))),
#  'Census Tract 9759.01, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975901'))),
#  'Census Tract 9758, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975800'))),
#  'Census Tract 9751, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975100'))),
#  'Census Tract 9757, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975700'))),
#  'Census Tract 9753, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975300'))),
#  'Census Tract 9756, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975600'))),
#  'Census Tract 9752, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975200'))),
#  'Census Tract 9755, Sullivan County, New Hampshire': censusgeo((('state', '33'), ('county', '019'), ('tract', '975500'))),
#  'Census Tract 11, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001100'))),
#  'Census Tract 26, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002600'))),
#  'Census Tract 104, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010400'))),
#  'Census Tract 122, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '012200'))),
#  'Census Tract 210, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '021000'))),
#  'Census Tract 250, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '025000'))),
#  'Census Tract 255, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '025500'))),
#  'Census Tract 17, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001700'))),
#  'Census Tract 18, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001800'))),
#  'Census Tract 2001, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '200100'))),
#  'Census Tract 107, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010700'))),
#  'Census Tract 115, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011500'))),
#  'Census Tract 171, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '017100'))),
#  'Census Tract 114.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011401'))),
#  'Census Tract 29.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002902'))),
#  'Census Tract 105, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010500'))),
#  'Census Tract 108, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010800'))),
#  'Census Tract 143, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '014300'))),
#  'Census Tract 162.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '016201'))),
#  'Census Tract 2.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000202'))),
#  'Census Tract 6, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000600'))),
#  'Census Tract 36.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003602'))),
#  'Census Tract 570, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '057000'))),
#  'Census Tract 550.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '055001'))),
#  'Census Tract 670, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '067000'))),
#  'Census Tract 692, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '069200'))),
#  'Census Tract 693, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '069300'))),
#  'Census Tract 1002, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '100200'))),
#  'Census Tract 510, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '051000'))),
#  'Census Tract 560, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '056000'))),
#  'Census Tract 620, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '062000'))),
#  'Census Tract 640, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '064000'))),
#  'Census Tract 691, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '069100'))),
#  'Census Tract 1031, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '103100'))),
#  'Census Tract 34, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003400'))),
#  'Census Tract 35, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003500'))),
#  'Census Tract 675.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '067501'))),
#  'Census Tract 7, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000700'))),
#  'Census Tract 24, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002400'))),
#  'Census Tract 12, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001200'))),
#  'Census Tract 15, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001500'))),
#  'Census Tract 22, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002200'))),
#  'Census Tract 28, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002800'))),
#  'Census Tract 109, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010900'))),
#  'Census Tract 110, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011000'))),
#  'Census Tract 190, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '019000'))),
#  'Census Tract 200, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '020000'))),
#  'Census Tract 2003, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '200300'))),
#  'Census Tract 9.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000902'))),
#  'Census Tract 13, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '001300'))),
#  'Census Tract 20, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002000'))),
#  'Census Tract 3, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000300'))),
#  'Census Tract 9.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000901'))),
#  'Census Tract 25, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002500'))),
#  'Census Tract 102, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '010200'))),
#  'Census Tract 112, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011200'))),
#  'Census Tract 113, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011300'))),
#  'Census Tract 152, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '015200'))),
#  'Census Tract 230, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '023000'))),
#  'Census Tract 675.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '067502'))),
#  'Census Tract 40, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '004000'))),
#  'Census Tract 500, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '050000'))),
#  'Census Tract 530, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '053000'))),
#  'Census Tract 580, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '058000'))),
#  'Census Tract 590, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '059000'))),
#  'Census Tract 600, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '060000'))),
#  'Census Tract 1001, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '100100'))),
#  'Census Tract 1061.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '106102'))),
#  'Census Tract 33.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003301'))),
#  'Census Tract 660, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '066000'))),
#  'Census Tract 2004, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '200400'))),
#  'Census Tract 9801.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '980101'))),
#  'Census Tract 310.02, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '031002'))),
#  'Census Tract 30.06, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '003006'))),
#  'Census Tract 310.01, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '031001'))),
#  'Census Tract 327.01, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032701'))),
#  'Census Tract 327.06, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032706'))),
#  'Census Tract 441, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '044100'))),
#  'Census Tract 442, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '044200'))),
#  'Census Tract 443, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '044300'))),
#  'Census Tract 38.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003801'))),
#  'Census Tract 37.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003701'))),
#  'Census Tract 37.03, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003703'))),
#  'Census Tract 38.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003802'))),
#  'Census Tract 39.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003901'))),
#  'Census Tract 39.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '003902'))),
#  'Census Tract 215, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '021500'))),
#  'Census Tract 630.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '063001'))),
#  'Census Tract 630.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '063002'))),
#  'Census Tract 650.05, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '065005'))),
#  'Census Tract 650.06, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '065006'))),
#  'Census Tract 650.07, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '065007'))),
#  'Census Tract 650.08, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '065008'))),
#  'Census Tract 1041.01, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '104101'))),
#  'Census Tract 1041.02, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '104102'))),
#  'Census Tract 1062, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '106200'))),
#  'Census Tract 1064, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '106400'))),
#  'Census Tract 1071, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '107100'))),
#  'Census Tract 1072, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '107200'))),
#  'Census Tract 1074, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '107400'))),
#  'Census Tract 1075, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '107500'))),
#  'Census Tract 9800.11, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '980011'))),
#  'Census Tract 9900, Rockingham County, New Hampshire': censusgeo((('state', '33'), ('county', '015'), ('tract', '990000'))),
#  'Census Tract 802.03, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '080203'))),
#  'Census Tract 802.04, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '080204'))),
#  'Census Tract 9714.02, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971402'))),
#  'Census Tract 9702, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970200'))),
#  'Census Tract 9704, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970400'))),
#  'Census Tract 9707, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970700'))),
#  'Census Tract 9709, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970900'))),
#  'Census Tract 9715, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971500'))),
#  'Census Tract 9701, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970100'))),
#  'Census Tract 9717, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971700'))),
#  'Census Tract 9714.01, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971401'))),
#  'Census Tract 9705, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970500'))),
#  'Census Tract 9706, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970600'))),
#  'Census Tract 9708, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '970800'))),
#  'Census Tract 9713, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971300'))),
#  'Census Tract 9710, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971000'))),
#  'Census Tract 9711, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971100'))),
#  'Census Tract 9716, Cheshire County, New Hampshire': censusgeo((('state', '33'), ('county', '005'), ('tract', '971600'))),
#  'Census Tract 329, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032900'))),
#  'Census Tract 400, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '040000'))),
#  'Census Tract 32, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '003200'))),
#  'Census Tract 328, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032800'))),
#  'Census Tract 330, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '033000'))),
#  'Census Tract 340, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '034000'))),
#  'Census Tract 440, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '044000'))),
#  'Census Tract 325, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032500'))),
#  'Census Tract 360, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '036000'))),
#  'Census Tract 370, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '037000'))),
#  'Census Tract 430.01, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '043001'))),
#  'Census Tract 324, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032400'))),
#  'Census Tract 350, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '035000'))),
#  'Census Tract 415, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '041500'))),
#  'Census Tract 425, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '042500'))),
#  'Census Tract 380, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '038000'))),
#  'Census Tract 30.01, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '003001'))),
#  'Census Tract 390, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '039000'))),
#  'Census Tract 300, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '030000'))),
#  'Census Tract 385, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '038500'))),
#  'Census Tract 31, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '003100'))),
#  'Census Tract 323, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032300'))),
#  'Census Tract 326, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032600'))),
#  'Census Tract 405, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '040500'))),
#  'Census Tract 430.02, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '043002'))),
#  'Census Tract 322, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032200'))),
#  'Census Tract 321, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '032100'))),
#  'Census Tract 410, Merrimack County, New Hampshire': censusgeo((('state', '33'), ('county', '013'), ('tract', '041000'))),
#  'Census Tract 9604, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960400'))),
#  'Census Tract 9605, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960500'))),
#  'Census Tract 9617, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961700'))),
#  'Census Tract 9618, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961800'))),
#  'Census Tract 9615, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961500'))),
#  'Census Tract 9611, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '961100'))),
#  'Census Tract 9601, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960100'))),
#  'Census Tract 9609, Grafton County, New Hampshire': censusgeo((('state', '33'), ('county', '009'), ('tract', '960900'))),
#  'Census Tract 885, Strafford County, New Hampshire': censusgeo((('state', '33'), ('county', '017'), ('tract', '088500'))),
#  'Census Tract 9664.01, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966401'))),
#  'Census Tract 9664.02, Belknap County, New Hampshire': censusgeo((('state', '33'), ('county', '001'), ('tract', '966402'))),
#  'Census Tract 2.03, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000203'))),
#  'Census Tract 2.04, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '000204'))),
#  'Census Tract 27.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002701'))),
#  'Census Tract 27.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '002702'))),
#  'Census Tract 111.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011102'))),
#  'Census Tract 111.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '011101'))),
#  'Census Tract 185.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '018501'))),
#  'Census Tract 185.02, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '018502'))),
#  'Census Tract 195.01, Hillsborough County, New Hampshire': censusgeo((('state', '33'), ('county', '011'), ('tract', '019501')))}

# %%
# test the variable availability using county = 001, before downloading all the variables.
test_df = censusdata.download('acs5', 2016, censusdata.censusgeo([('state', '25'), ('tract', '*')]),
                                            var_list)
test_df.columns = var_names
pd.set_option('display.max_rows', 500)
print(np.sum(test_df.isna()))
pd.set_option('display.max_rows', 10) # sw: very high quality
# Out:
# pop_total                    0
# sex_total                    0
# sex_male                     0
# sex_female                   0
# age_median                   0
# households                   0
# race_total                   0
# race_white                   0
# race_black                   0
# race_native                  0
# race_asian                   0
# inc_total_pop                0
# inc_no_pop                   0
# inc_with_pop                 0
# inc_pop_10k                  0
# inc_pop_1k_15k               0
# inc_pop_15k_25k              0
# inc_pop_25k_35k              0
# inc_pop_35k_50k              0
# inc_pop_50k_65k              0
# inc_pop_65k_75k              0
# inc_pop_75k                  0
# inc_median_ind               0
# travel_total_to_work         0
# travel_driving_to_work       0
# travel_pt_to_work            0
# travel_taxi_to_work          0
# travel_cycle_to_work         0
# travel_walk_to_work          0
# travel_work_from_home        0
# edu_total_pop                0
# bachelor_male_25_34          0
# master_phd_male_25_34        0
# bachelor_male_35_44          0
# master_phd_male_35_44        0
# bachelor_male_45_64          0
# master_phd_male_45_64        0
# bachelor_male_65_over        0
# master_phd_male_65_over      0
# bachelor_female_25_34        0
# master_phd_female_25_34      0
# bachelor_female_35_44        0
# master_phd_female_35_44      0
# bachelor_female_45_64        0
# master_phd_female_45_64      0
# bachelor_female_65_over      0
# master_phd_female_65_over    0
# edu_total                    0
# edu_bachelor                 0
# edu_master                   0
# edu_phd                      0
# inc_median_household         0
# inc_per_capita               0
# employment_total_labor       0
# employment_employed          0
# employment_unemployed        0
# housing_units_total          0
# housing_units_occupied       0
# housing_units_vacant         0
# rent_median                  0
# property_value_total         0
# property_value_median        0
# vehicle_total_imputed        0
# dtype: int64

# %%
# download ma_ct_2016, ma_ct_2018, nh_ct_2016, nh_ct_2018.
ma_ct_2016 = censusdata.download('acs5', 2016, censusdata.censusgeo([('state', '25'), ('tract', '*')]), var_list)
ma_ct_2018 = censusdata.download('acs5', 2018, censusdata.censusgeo([('state', '25'), ('tract', '*')]), var_list)
nh_ct_2016 = censusdata.download('acs5', 2016, censusdata.censusgeo([('state', '33'), ('tract', '*')]), var_list)
nh_ct_2018 = censusdata.download('acs5', 2018, censusdata.censusgeo([('state', '33'), ('tract', '*')]), var_list)

# %%
# download fl_ct_2016, fl_ct_2018, il_ct_2016, il_ct_2018.
fl_ct_2016 = censusdata.download('acs5', 2016, censusdata.censusgeo([('state', '12'), ('tract', '*')]), var_list)
fl_ct_2018 = censusdata.download('acs5', 2018, censusdata.censusgeo([('state', '12'), ('tract', '*')]), var_list)
il_ct_2016 = censusdata.download('acs5', 2016, censusdata.censusgeo([('state', '17'), ('tract', '*')]), var_list)
il_ct_2018 = censusdata.download('acs5', 2018, censusdata.censusgeo([('state', '17'), ('tract', '*')]), var_list)

# %%
# replace the column names
ma_ct_2016.columns = var_names
ma_ct_2018.columns = var_names
nh_ct_2016.columns = var_names
nh_ct_2018.columns = var_names
fl_ct_2016.columns = var_names
fl_ct_2018.columns = var_names
il_ct_2016.columns = var_names
il_ct_2018.columns = var_names

# add year
ma_ct_2016['year'] = 2016
ma_ct_2018['year'] = 2018
nh_ct_2016['year'] = 2016
nh_ct_2018['year'] = 2018
fl_ct_2016['year'] = 2016
fl_ct_2018['year'] = 2018
il_ct_2016['year'] = 2016
il_ct_2018['year'] = 2018

# add state
ma_ct_2016['state'] = 'MA'
ma_ct_2018['state'] = 'MA'
nh_ct_2016['state'] = 'NH'
nh_ct_2018['state'] = 'NH'
fl_ct_2016['state'] = 'FL'
fl_ct_2018['state'] = 'FL'
il_ct_2016['state'] = 'IL'
il_ct_2018['state'] = 'IL'

# %%
# concat the MA and NH files, since the two cannot cover the area of the mobility data
# no need to concat the FL or IL files
boston_metro_ct_2016_df = pd.concat([ma_ct_2016, nh_ct_2016], axis = 0)
boston_metro_ct_2018_df = pd.concat([ma_ct_2018, nh_ct_2018], axis = 0)

# %%
# add the FIPS info. Change the idx. 
def add_fips(df_state):
    state_fips=[]
    county_fips=[]
    tract_fips=[]
    full_ct_fips=[]
    
    for i in range(df_state.shape[0]):
        state_fips.append(df_state.index[i].params()[0][1])  
        county_fips.append(df_state.index[i].params()[1][1])  
        tract_fips.append(df_state.index[i].params()[2][1])
        full_ct_fips.append(df_state.index[i].params()[0][1]
                            +df_state.index[i].params()[1][1]
                            +df_state.index[i].params()[2][1])
    
    df_state['state_fips'] = state_fips
    df_state['county_fips'] = county_fips
    df_state['tract_fips'] = tract_fips
    df_state['full_ct_fips'] = full_ct_fips
    
    df_state.reset_index(drop = True, inplace = True)
    return df_state

# apply to 2016 and 2018 
boston_metro_ct_2016_df_v1 = add_fips(boston_metro_ct_2016_df)
boston_metro_ct_2018_df_v1 = add_fips(boston_metro_ct_2018_df)
fl_ct_2016_df_v1 = add_fips(fl_ct_2016)
fl_ct_2018_df_v1 = add_fips(fl_ct_2018)
il_ct_2016_df_v1 = add_fips(il_ct_2016)
il_ct_2018_df_v1 = add_fips(il_ct_2018)

# %%
boston_metro_ct_2016_df_v1
# Out:
#       pop_total  sex_total  sex_male  sex_female  age_median  households  \
# 0          6264       6264      3009        3255        32.0        1972
# 1          4905       4905      2394        2511        39.2        1781
# 2          4504       4504      2333        2171        47.2        1563
# 3          5287       5287      2689        2598        41.6        2157
# 4          5125       5125      2555        2570        49.6        1762
# ...         ...        ...       ...         ...         ...         ...
# 1768       3276       3276      1757        1519        31.7        1716
# 1769       3549       3549      1588        1961        31.8        1749
# 1770       2078       2078      1027        1051        44.3         852
# 1771       1420       1420       706         714        46.2         559
# 1772       1738       1738       913         825        49.8         668
#
#       race_total  race_white  race_black  race_native  ...  rent_median  \
# 0           6264        2827        2542            8  ...         1244
# 1           4905        2021        2264            0  ...          505
# 2           4504        4181          35            0  ...         1563
# 3           5287        4058          38            0  ...          958
# 4           5125        4390          33            9  ...         2085
# ...          ...         ...         ...          ...  ...          ...
# 1768        3276        2095         116           12  ...         1239
# 1769        3549        2593         107            3  ...         1216
# 1770        2078        2054           0            0  ...          729
# 1771        1420        1365           0            0  ...         1861
# 1772        1738        1693           8            0  ...         1098
#
#       property_value_total  property_value_median  vehicle_total_imputed  \
# 0                     1257                 273100                   2786
# 1                      948                 188000                   2180
# 2                     1402                 597600                   2292
# 3                     1581                 500200                   2963
# 4                     1694                 757900                   2447
# ...                    ...                    ...                    ...
# 1768                   257                 153200                   1860
# 1769                   330                 122900                   2368
# 1770                   600                 121700                   1026
# 1771                   513                 283800                    785
# 1772                   614                 260300                    957
#
#       year  state  state_fips  county_fips  tract_fips  full_ct_fips
# 0     2016     MA          25          023      510700   25023510700
# 1     2016     MA          25          023      511200   25023511200
# 2     2016     MA          25          009      253203   25009253203
# 3     2016     MA          25          017      388100   25017388100
# 4     2016     MA          25          017      362100   25017362100
# ...    ...    ...         ...          ...         ...           ...
# 1768  2016     NH          33          011      011102   33011011102
# 1769  2016     NH          33          011      011101   33011011101
# 1770  2016     NH          33          011      018501   33011018501
# 1771  2016     NH          33          011      018502   33011018502
# 1772  2016     NH          33          011      019501   33011019501
#
# [1773 rows x 69 columns]

# %%
fl_ct_2016_df_v1
# Out:
#       pop_total  sex_total  sex_male  sex_female  age_median  households  \
# 0          6082       6082      3284        2798        49.3        2106
# 1          7379       7379      3212        4167        46.3        2365
# 2          9873       9873      4798        5075        35.6        3035
# 3          2583       2583      1168        1415        58.1        1504
# 4          4566       4566      2209        2357        41.8        1921
# ...         ...        ...       ...         ...         ...         ...
# 4240       2441       2441      1205        1236        58.3        1305
# 4241       3965       3965      1902        2063        50.3        1704
# 4242       3391       3391      1455        1936        59.4        1859
# 4243       3015       3015      1359        1656        47.5        1347
# 4244       3939       3939      1796        2143        48.1        1750
#
#       race_total  race_white  race_black  race_native  ...  rent_median  \
# 0           6082        5586         332           28  ...         1108
# 1           7379        5841         825            7  ...          914
# 2           9873        8954         422           15  ...         1185
# 3           2583        2540           4            0  ...          916
# 4           4566        4263           9            0  ...         1117
# ...          ...         ...         ...          ...  ...          ...
# 4240        2441        2272          26            0  ...         1148
# 4241        3965        3620         169            0  ...         1453
# 4242        3391        3118          53            0  ...         1638
# 4243        3015        2779          70            0  ...         1337
# 4244        3939        2856         643            0  ...         1207
#
#       property_value_total  property_value_median  vehicle_total_imputed  \
# 0                     1503                 158600                   2726
# 1                     1400                 132400                   2694
# 2                     1851                 165100                   4013
# 3                      846                 114400                   1202
# 4                     1082                 237200                   2320
# ...                    ...                    ...                    ...
# 4240                   912                 405600                   1131
# 4241                  1260                 435500                   2001
# 4242                  1123                 240500                   1395
# 4243                   980                 199500                   1855
# 4244                   988                 363900                   1813
#
#       year  state  state_fips  county_fips  tract_fips  full_ct_fips
# 0     2016     FL          12          071      010303   12071010303
# 1     2016     FL          12          071      010307   12071010307
# 2     2016     FL          12          071      010103   12071010103
# 3     2016     FL          12          071      001701   12071001701
# 4     2016     FL          12          071      001801   12071001801
# ...    ...    ...         ...          ...         ...           ...
# 4240  2016     FL          12          099      000511   12099000511
# 4241  2016     FL          12          099      000703   12099000703
# 4242  2016     FL          12          099      000803   12099000803
# 4243  2016     FL          12          099      000804   12099000804
# 4244  2016     FL          12          099      000904   12099000904
#
# [4245 rows x 69 columns]

# %%
# check the na.
pd.set_option('display.max_rows', 500)
# print(np.sum(boston_metro_bg_2016_df_v1.isna()))
print(np.sum(boston_metro_ct_2018_df_v1.isna()))
pd.set_option('display.max_rows', 10)
# Out:
# pop_total                    0
# sex_total                    0
# sex_male                     0
# sex_female                   0
# age_median                   0
# households                   0
# race_total                   0
# race_white                   0
# race_black                   0
# race_native                  0
# race_asian                   0
# inc_total_pop                0
# inc_no_pop                   0
# inc_with_pop                 0
# inc_pop_10k                  0
# inc_pop_1k_15k               0
# inc_pop_15k_25k              0
# inc_pop_25k_35k              0
# inc_pop_35k_50k              0
# inc_pop_50k_65k              0
# inc_pop_65k_75k              0
# inc_pop_75k                  0
# inc_median_ind               0
# travel_total_to_work         0
# travel_driving_to_work       0
# travel_pt_to_work            0
# travel_taxi_to_work          0
# travel_cycle_to_work         0
# travel_walk_to_work          0
# travel_work_from_home        0
# edu_total_pop                0
# bachelor_male_25_34          0
# master_phd_male_25_34        0
# bachelor_male_35_44          0
# master_phd_male_35_44        0
# bachelor_male_45_64          0
# master_phd_male_45_64        0
# bachelor_male_65_over        0
# master_phd_male_65_over      0
# bachelor_female_25_34        0
# master_phd_female_25_34      0
# bachelor_female_35_44        0
# master_phd_female_35_44      0
# bachelor_female_45_64        0
# master_phd_female_45_64      0
# bachelor_female_65_over      0
# master_phd_female_65_over    0
# edu_total                    0
# edu_bachelor                 0
# edu_master                   0
# edu_phd                      0
# inc_median_household         0
# inc_per_capita               0
# employment_total_labor       0
# employment_employed          0
# employment_unemployed        0
# housing_units_total          0
# housing_units_occupied       0
# housing_units_vacant         0
# rent_median                  0
# property_value_total         0
# property_value_median        0
# vehicle_total_imputed        0
# year                         0
# state                        0
# state_fips                   0
# county_fips                  0
# tract_fips                   0
# full_ct_fips                 0
# dtype: int64

# %% [markdown]
# # Save

# %%
with open('../../data/01_raw/boston_metro_ct_2016_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_ct_2016_df_v1, f)
    
with open('../../data/01_raw/boston_metro_ct_2018_df.pickle', 'wb') as f:
    pickle.dump(boston_metro_ct_2018_df_v1, f)

# %%
with open('../../data/01_raw/florida_ct_2016_df.pickle', 'wb') as f:
    pickle.dump(fl_ct_2016_df_v1, f)
    
with open('../../data/01_raw/florida_ct_2018_df.pickle', 'wb') as f:
    pickle.dump(fl_ct_2018_df_v1, f)

# %%
with open('../../data/01_raw/illinois_ct_2016_df.pickle', 'wb') as f:
    pickle.dump(il_ct_2016_df_v1, f)
    
with open('../../data/01_raw/illinois_ct_2018_df.pickle', 'wb') as f:
    pickle.dump(il_ct_2018_df_v1, f)
